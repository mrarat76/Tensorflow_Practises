# %% [markdown]
# <a href="https://colab.research.google.com/github/mrarat76/Tensorflow_Practises/blob/main/libarat_simsek.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install data-preprocessing-lib-byarat

# %%
# !pip install --upgrade data-preprocessing-lib-byarat
# Out:
# ...
#   Using cached data_preprocessing_lib_byarat-1.8.0-py3-none-any.whl (15 kB)
# ...
#   Using cached contractions-0.1.73-py2.py3-none-any.whl (8.7 kB)
# ...
#   Using cached emoji-2.12.1-py3-none-any.whl (431 kB)
# ...
#   Using cached pyspellchecker-0.8.1-py3-none-any.whl (6.8 MB)
# ...
#   Using cached textsearch-0.0.24-py2.py3-none-any.whl (7.6 kB)
# ...
#   Using cached anyascii-0.3.2-py3-none-any.whl (289 kB)
# ...
#   Using cached pyahocorasick-2.1.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (110 kB)
# ...

# %%
# !pip show data-preprocessing-lib-byarat
# Out:
# Name: data-preprocessing-lib-byarat
# Version: 1.9.0
# Summary: An easy peasy comprehensive library for data preprocessing tasks
# Home-page:
# Author: Mehdi Miraç ARAT, Latif Şimşek
# Author-email: mehdimirac.arat@stu.fsm.edu.tr, latif.simsek@stu.fsm.edu.tr
# License:
# Location: /usr/local/lib/python3.10/dist-packages
# Requires: beautifulsoup4, contractions, emoji, nltk, numpy, pandas, pyspellchecker, scikit-learn
# Required-by:

# %%
# !pip install beautifulsoup4

# !pip install contractions

# !pip install emoji

# !pip install pyspellchecker

# %%
# !pip install nltk

# %%
import nltk

# NLTK veri kümelerini indir
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
import pandas as pd
from data_preprocessing_lib_byarat import TextCleaner

data = {'text': ["Hello World! This is a test. 🤣"]}
df = pd.DataFrame(data)
cleaner = TextCleaner()




# Clean text column
df_clean = TextCleaner.clean_column(df.copy(), 'text')

print("Clean Column:")
print(df_clean)
# Out:
# Clean Column:
#                  text
# 0  hello world test 🤣

# %%
data = pd.read_csv('/content/synthetic_sample_data_minimal.csv')
sample = pd.DataFrame(data)
sample
# Out:
#      Movie Id            Genre Release Date    Rating  \
# 0   TOYHANVUR           Horror   07/07/1985  9.750176
# 1   CORCILSLF      Documentary   05/08/1999  7.912876
# 2   UBWUVIHEL        Adventure   08/05/1996  3.116053
# 3   CGHMHKJHH          Fantasy   21/07/2018  8.811783
# 4   WMLWHTAMN          Fantasy   28/10/2011  5.250991
# 5   REKCPGLOJ           Comedy   04/06/2013  8.676586
# 6   GSDOQQRPD          Western   25/12/1995  9.191819
# 7   VMIYHZNZJ        Adventure   23/03/2018  9.459478
# 8   XVHGPYBBL          Mystery   19/06/2002  9.125866
# 9   NNZFDYZTH          History   16/02/2019  9.232197
# 10  VZTEXQGBB           Comedy   22/01/2018  8.912548
# 11  XSPIAJYJM          Fantasy   19/11/1985  8.561358
# 12  VFXKEREAP          Fantasy   29/07/1992  7.742613
# 13  MCCASXIDK            Crime   26/12/2003  9.727619
# 14  MTUOJCLUA           Horror   03/03/1989  6.913383
# 15  DBQTOTADE            Drama   23/10/1990  8.276999
# ...

# %%
from data_preprocessing_lib_byarat import MissingValueHandler, OutlierHandler, Scaler, TextCleaner, FeatureEngineer, DataTypeConverter, CategoricalEncoder, DateTimeHandler

# %% [markdown]
# ##**CATEGORICAL ENCODE**

# %%
dataencoded = CategoricalEncoder()

# %%
encod=dataencoded.one_hot_encode(data,"Shooting Location")
encod
# Out:
#      Movie Id            Genre Release Date    Rating  \
# 0   TOYHANVUR           Horror   07/07/1985  9.750176
# 1   CORCILSLF      Documentary   05/08/1999  7.912876
# 2   UBWUVIHEL        Adventure   08/05/1996  3.116053
# 3   CGHMHKJHH          Fantasy   21/07/2018  8.811783
# 4   WMLWHTAMN          Fantasy   28/10/2011  5.250991
# 5   REKCPGLOJ           Comedy   04/06/2013  8.676586
# 6   GSDOQQRPD          Western   25/12/1995  9.191819
# 7   VMIYHZNZJ        Adventure   23/03/2018  9.459478
# 8   XVHGPYBBL          Mystery   19/06/2002  9.125866
# 9   NNZFDYZTH          History   16/02/2019  9.232197
# 10  VZTEXQGBB           Comedy   22/01/2018  8.912548
# 11  XSPIAJYJM          Fantasy   19/11/1985  8.561358
# 12  VFXKEREAP          Fantasy   29/07/1992  7.742613
# 13  MCCASXIDK            Crime   26/12/2003  9.727619
# 14  MTUOJCLUA           Horror   03/03/1989  6.913383
# 15  DBQTOTADE            Drama   23/10/1990  8.276999
# ...

# %%
encode=dataencoded.label_encode(data,"Shooting Location")
encode
# Out:
#      Movie Id            Genre Release Date    Rating  \
# 0   TOYHANVUR           Horror   07/07/1985  9.750176
# 1   CORCILSLF      Documentary   05/08/1999  7.912876
# 2   UBWUVIHEL        Adventure   08/05/1996  3.116053
# 3   CGHMHKJHH          Fantasy   21/07/2018  8.811783
# 4   WMLWHTAMN          Fantasy   28/10/2011  5.250991
# 5   REKCPGLOJ           Comedy   04/06/2013  8.676586
# 6   GSDOQQRPD          Western   25/12/1995  9.191819
# 7   VMIYHZNZJ        Adventure   23/03/2018  9.459478
# 8   XVHGPYBBL          Mystery   19/06/2002  9.125866
# 9   NNZFDYZTH          History   16/02/2019  9.232197
# 10  VZTEXQGBB           Comedy   22/01/2018  8.912548
# 11  XSPIAJYJM          Fantasy   19/11/1985  8.561358
# 12  VFXKEREAP          Fantasy   29/07/1992  7.742613
# 13  MCCASXIDK            Crime   26/12/2003  9.727619
# 14  MTUOJCLUA           Horror   03/03/1989  6.913383
# 15  DBQTOTADE            Drama   23/10/1990  8.276999
# ...

# %%
encoded=dataencoded.label_encode(data,"Genre")
encoded
# Out:
#      Movie Id  Genre Release Date    Rating  \
# 0   TOYHANVUR      7   07/07/1985  9.750176
# 1   CORCILSLF      3   05/08/1999  7.912876
# 2   UBWUVIHEL      0   08/05/1996  3.116053
# 3   CGHMHKJHH      5   21/07/2018  8.811783
# 4   WMLWHTAMN      5   28/10/2011  5.250991
# 5   REKCPGLOJ      1   04/06/2013  8.676586
# 6   GSDOQQRPD     12   25/12/1995  9.191819
# 7   VMIYHZNZJ      0   23/03/2018  9.459478
# 8   XVHGPYBBL      8   19/06/2002  9.125866
# 9   NNZFDYZTH      6   16/02/2019  9.232197
# 10  VZTEXQGBB      1   22/01/2018  8.912548
# 11  XSPIAJYJM      5   19/11/1985  8.561358
# 12  VFXKEREAP      5   29/07/1992  7.742613
# 13  MCCASXIDK      2   26/12/2003  9.727619
# 14  MTUOJCLUA      7   03/03/1989  6.913383
# 15  DBQTOTADE      4   23/10/1990  8.276999
# 16  TKBEDDCMZ     11   26/06/2009  7.591583
# 17  CDRJDLRCH      6   14/12/2005  9.603778
# 18  WWAZEJQVI      4   12/08/1995  9.801080
# 19  IDFPFANWC      5   20/11/2015  9.227341
# ...

# %%
df_freq = dataencoded.frequency_encode(data, 'Genre')
print("Frequency Encoding:")
df_freq
# Out:
# Frequency Encoding:
#      Movie Id  Genre Release Date    Rating  \
# 0   TOYHANVUR      7   07/07/1985  9.750176
# 1   CORCILSLF      3   05/08/1999  7.912876
# 2   UBWUVIHEL      0   08/05/1996  3.116053
# 3   CGHMHKJHH      5   21/07/2018  8.811783
# 4   WMLWHTAMN      5   28/10/2011  5.250991
# 5   REKCPGLOJ      1   04/06/2013  8.676586
# 6   GSDOQQRPD     12   25/12/1995  9.191819
# 7   VMIYHZNZJ      0   23/03/2018  9.459478
# 8   XVHGPYBBL      8   19/06/2002  9.125866
# 9   NNZFDYZTH      6   16/02/2019  9.232197
# 10  VZTEXQGBB      1   22/01/2018  8.912548
# 11  XSPIAJYJM      5   19/11/1985  8.561358
# 12  VFXKEREAP      5   29/07/1992  7.742613
# 13  MCCASXIDK      2   26/12/2003  9.727619
# 14  MTUOJCLUA      7   03/03/1989  6.913383
# 15  DBQTOTADE      4   23/10/1990  8.276999
# 16  TKBEDDCMZ     11   26/06/2009  7.591583
# 17  CDRJDLRCH      6   14/12/2005  9.603778
# 18  WWAZEJQVI      4   12/08/1995  9.801080
# 19  IDFPFANWC      5   20/11/2015  9.227341
# ...

# %%
# !pip install --upgrade data-preprocessing-lib-byarat
# Out:
# ...
# ERROR: Operation cancelled by user

# %%
df_binary = dataencoded.binary_encode_update(data, 'Genre')
print("Binary Encoding:")
df_binary
# Out:
# Binary Encoding:
#      Movie Id Release Date    Rating  \
# 0   TOYHANVUR   07/07/1985  9.750176
# 1   CORCILSLF   05/08/1999  7.912876
# 2   UBWUVIHEL   08/05/1996  3.116053
# 3   CGHMHKJHH   21/07/2018  8.811783
# 4   WMLWHTAMN   28/10/2011  5.250991
# 5   REKCPGLOJ   04/06/2013  8.676586
# 6   GSDOQQRPD   25/12/1995  9.191819
# 7   VMIYHZNZJ   23/03/2018  9.459478
# 8   XVHGPYBBL   19/06/2002  9.125866
# 9   NNZFDYZTH   16/02/2019  9.232197
# 10  VZTEXQGBB   22/01/2018  8.912548
# 11  XSPIAJYJM   19/11/1985  8.561358
# 12  VFXKEREAP   29/07/1992  7.742613
# 13  MCCASXIDK   26/12/2003  9.727619
# 14  MTUOJCLUA   03/03/1989  6.913383
# 15  DBQTOTADE   23/10/1990  8.276999
# 16  TKBEDDCMZ   26/06/2009  7.591583
# 17  CDRJDLRCH   14/12/2005  9.603778
# 18  WWAZEJQVI   12/08/1995  9.801080
# 19  IDFPFANWC   20/11/2015  9.227341
# 20  QTIYFBNML   02/08/2005  7.858370
# 21  RQMTIJYHD   15/08/1997  5.395632
# 22  GEGWEHHWS   06/12/2001  8.336223
# 23  QSUPSGILT   04/02/2002  7.216878
# ...

# %%
encoded_data_genre = dataencoded.ordinal_encode(sample, 'Genre')
print("Ordinal Encoded 'Genre' Column:")
encoded_data_genre
# Out:
# Ordinal Encoded 'Genre' Column:
#      Movie Id  Genre Release Date    Rating  \
# 0   TOYHANVUR    7.0   07/07/1985  9.750176
# 1   CORCILSLF    3.0   05/08/1999  7.912876
# 2   UBWUVIHEL    0.0   08/05/1996  3.116053
# 3   CGHMHKJHH    5.0   21/07/2018  8.811783
# 4   WMLWHTAMN    5.0   28/10/2011  5.250991
# 5   REKCPGLOJ    1.0   04/06/2013  8.676586
# 6   GSDOQQRPD   12.0   25/12/1995  9.191819
# 7   VMIYHZNZJ    0.0   23/03/2018  9.459478
# 8   XVHGPYBBL    8.0   19/06/2002  9.125866
# 9   NNZFDYZTH    6.0   16/02/2019  9.232197
# 10  VZTEXQGBB    1.0   22/01/2018  8.912548
# 11  XSPIAJYJM    5.0   19/11/1985  8.561358
# 12  VFXKEREAP    5.0   29/07/1992  7.742613
# 13  MCCASXIDK    2.0   26/12/2003  9.727619
# 14  MTUOJCLUA    7.0   03/03/1989  6.913383
# 15  DBQTOTADE    4.0   23/10/1990  8.276999
# 16  TKBEDDCMZ   11.0   26/06/2009  7.591583
# 17  CDRJDLRCH    6.0   14/12/2005  9.603778
# 18  WWAZEJQVI    4.0   12/08/1995  9.801080
# ...

# %%
encoded_data_genre = dataencoded.target_encode(sample, 'Genre', 'Rating')
print("Target Encoded 'Genre' Column:")
encoded_data_genre
# Out:
# Target Encoded 'Genre' Column:
#      Movie Id  Genre Release Date    Rating  \
# 0   TOYHANVUR    7.0   07/07/1985  9.750176
# 1   CORCILSLF    3.0   05/08/1999  7.912876
# 2   UBWUVIHEL    0.0   08/05/1996  3.116053
# 3   CGHMHKJHH    5.0   21/07/2018  8.811783
# 4   WMLWHTAMN    5.0   28/10/2011  5.250991
# 5   REKCPGLOJ    1.0   04/06/2013  8.676586
# 6   GSDOQQRPD   12.0   25/12/1995  9.191819
# 7   VMIYHZNZJ    0.0   23/03/2018  9.459478
# 8   XVHGPYBBL    8.0   19/06/2002  9.125866
# 9   NNZFDYZTH    6.0   16/02/2019  9.232197
# 10  VZTEXQGBB    1.0   22/01/2018  8.912548
# 11  XSPIAJYJM    5.0   19/11/1985  8.561358
# 12  VFXKEREAP    5.0   29/07/1992  7.742613
# 13  MCCASXIDK    2.0   26/12/2003  9.727619
# 14  MTUOJCLUA    7.0   03/03/1989  6.913383
# 15  DBQTOTADE    4.0   23/10/1990  8.276999
# 16  TKBEDDCMZ   11.0   26/06/2009  7.591583
# 17  CDRJDLRCH    6.0   14/12/2005  9.603778
# 18  WWAZEJQVI    4.0   12/08/1995  9.801080
# ...

# %% [markdown]
# ##**Data Type Conveerter**

# %%
dataconv = DataTypeConverter()

# %%
numeric_data = dataconv.to_numeric(data.copy(), 'Budget in USD')
print("Numeric Column Converted Data:")
numeric_data
# Out:
# Numeric Column Converted Data:
#      Movie Id Release Date    Rating  \
# 0   TOYHANVUR   07/07/1985  9.750176
# 1   CORCILSLF   05/08/1999  7.912876
# 2   UBWUVIHEL   08/05/1996  3.116053
# 3   CGHMHKJHH   21/07/2018  8.811783
# 4   WMLWHTAMN   28/10/2011  5.250991
# 5   REKCPGLOJ   04/06/2013  8.676586
# 6   GSDOQQRPD   25/12/1995  9.191819
# 7   VMIYHZNZJ   23/03/2018  9.459478
# 8   XVHGPYBBL   19/06/2002  9.125866
# 9   NNZFDYZTH   16/02/2019  9.232197
# 10  VZTEXQGBB   22/01/2018  8.912548
# 11  XSPIAJYJM   19/11/1985  8.561358
# 12  VFXKEREAP   29/07/1992  7.742613
# 13  MCCASXIDK   26/12/2003  9.727619
# 14  MTUOJCLUA   03/03/1989  6.913383
# 15  DBQTOTADE   23/10/1990  8.276999
# 16  TKBEDDCMZ   26/06/2009  7.591583
# 17  CDRJDLRCH   14/12/2005  9.603778
# 18  WWAZEJQVI   12/08/1995  9.801080
# 19  IDFPFANWC   20/11/2015  9.227341
# 20  QTIYFBNML   02/08/2005  7.858370
# 21  RQMTIJYHD   15/08/1997  5.395632
# 22  GEGWEHHWS   06/12/2001  8.336223
# ...

# %%
categorical_data = dataconv.to_categorical(sample, 'Genre')
print("\nCategorical Column Converted Data:")
categorical_data
# Out:
# Categorical Column Converted Data:
#      Movie Id Genre Release Date    Rating  \
# 0   TOYHANVUR   7.0   07/07/1985  9.750176
# 1   CORCILSLF   3.0   05/08/1999  7.912876
# 2   UBWUVIHEL   0.0   08/05/1996  3.116053
# 3   CGHMHKJHH   5.0   21/07/2018  8.811783
# 4   WMLWHTAMN   5.0   28/10/2011  5.250991
# 5   REKCPGLOJ   1.0   04/06/2013  8.676586
# 6   GSDOQQRPD  12.0   25/12/1995  9.191819
# 7   VMIYHZNZJ   0.0   23/03/2018  9.459478
# 8   XVHGPYBBL   8.0   19/06/2002  9.125866
# 9   NNZFDYZTH   6.0   16/02/2019  9.232197
# 10  VZTEXQGBB   1.0   22/01/2018  8.912548
# 11  XSPIAJYJM   5.0   19/11/1985  8.561358
# 12  VFXKEREAP   5.0   29/07/1992  7.742613
# 13  MCCASXIDK   2.0   26/12/2003  9.727619
# 14  MTUOJCLUA   7.0   03/03/1989  6.913383
# 15  DBQTOTADE   4.0   23/10/1990  8.276999
# 16  TKBEDDCMZ  11.0   26/06/2009  7.591583
# 17  CDRJDLRCH   6.0   14/12/2005  9.603778
# 18  WWAZEJQVI   4.0   12/08/1995  9.801080
# 19  IDFPFANWC   5.0   20/11/2015  9.227341
# ...

# %%
datetime_data = dataconv.to_datetime(sample, 'Release Date')
print("\nDatetime Column Converted Data:")
datetime_data
# Out:
# Datetime Column Converted Data:
#      Movie Id Genre Release Date    Rating  \
# 0   TOYHANVUR   7.0   1985-07-07  9.750176
# 1   CORCILSLF   3.0   1999-05-08  7.912876
# 2   UBWUVIHEL   0.0   1996-08-05  3.116053
# 3   CGHMHKJHH   5.0          NaT  8.811783
# 4   WMLWHTAMN   5.0          NaT  5.250991
# 5   REKCPGLOJ   1.0   2013-04-06  8.676586
# 6   GSDOQQRPD  12.0          NaT  9.191819
# 7   VMIYHZNZJ   0.0          NaT  9.459478
# 8   XVHGPYBBL   8.0          NaT  9.125866
# 9   NNZFDYZTH   6.0          NaT  9.232197
# 10  VZTEXQGBB   1.0          NaT  8.912548
# 11  XSPIAJYJM   5.0          NaT  8.561358
# 12  VFXKEREAP   5.0          NaT  7.742613
# 13  MCCASXIDK   2.0          NaT  9.727619
# 14  MTUOJCLUA   7.0   1989-03-03  6.913383
# 15  DBQTOTADE   4.0          NaT  8.276999
# 16  TKBEDDCMZ  11.0          NaT  7.591583
# 17  CDRJDLRCH   6.0          NaT  9.603778
# 18  WWAZEJQVI   4.0   1995-12-08  9.801080
# 19  IDFPFANWC   5.0          NaT  9.227341
# ...

# %% [markdown]
# ##**Date Time Handler**

# %%
handler = DateTimeHandler()

# %%
date_parts_data = handler.extract_date_parts(data.copy(), 'Release Date')
print("Extracted Date Parts Data:")
date_parts_data
# Out:
# Extracted Date Parts Data:
#      Movie Id Release Date    Rating  \
# 0   TOYHANVUR   1985-07-07  9.750176
# 1   CORCILSLF   1999-05-08  7.912876
# 2   UBWUVIHEL   1996-08-05  3.116053
# 3   CGHMHKJHH          NaT  8.811783
# 4   WMLWHTAMN          NaT  5.250991
# 5   REKCPGLOJ   2013-04-06  8.676586
# 6   GSDOQQRPD          NaT  9.191819
# 7   VMIYHZNZJ          NaT  9.459478
# 8   XVHGPYBBL          NaT  9.125866
# 9   NNZFDYZTH          NaT  9.232197
# 10  VZTEXQGBB          NaT  8.912548
# 11  XSPIAJYJM          NaT  8.561358
# 12  VFXKEREAP          NaT  7.742613
# 13  MCCASXIDK          NaT  9.727619
# 14  MTUOJCLUA   1989-03-03  6.913383
# 15  DBQTOTADE          NaT  8.276999
# 16  TKBEDDCMZ          NaT  7.591583
# 17  CDRJDLRCH          NaT  9.603778
# 18  WWAZEJQVI   1995-12-08  9.801080
# 19  IDFPFANWC          NaT  9.227341
# 20  QTIYFBNML   2005-02-08  7.858370
# 21  RQMTIJYHD          NaT  5.395632
# 22  GEGWEHHWS   2001-06-12  8.336223
# ...

# %%
year_data = handler.extract_year(data.copy(), 'Release Date')
print("\nExtracted Year Data:")
year_data
# Out:
# Extracted Year Data:
#      Movie Id Release Date    Rating  \
# 0   TOYHANVUR   1985-07-07  9.750176
# 1   CORCILSLF   1999-05-08  7.912876
# 2   UBWUVIHEL   1996-08-05  3.116053
# 3   CGHMHKJHH          NaT  8.811783
# 4   WMLWHTAMN          NaT  5.250991
# 5   REKCPGLOJ   2013-04-06  8.676586
# 6   GSDOQQRPD          NaT  9.191819
# 7   VMIYHZNZJ          NaT  9.459478
# 8   XVHGPYBBL          NaT  9.125866
# 9   NNZFDYZTH          NaT  9.232197
# 10  VZTEXQGBB          NaT  8.912548
# 11  XSPIAJYJM          NaT  8.561358
# 12  VFXKEREAP          NaT  7.742613
# 13  MCCASXIDK          NaT  9.727619
# 14  MTUOJCLUA   1989-03-03  6.913383
# 15  DBQTOTADE          NaT  8.276999
# 16  TKBEDDCMZ          NaT  7.591583
# 17  CDRJDLRCH          NaT  9.603778
# 18  WWAZEJQVI   1995-12-08  9.801080
# 19  IDFPFANWC          NaT  9.227341
# 20  QTIYFBNML   2005-02-08  7.858370
# 21  RQMTIJYHD          NaT  5.395632
# 22  GEGWEHHWS   2001-06-12  8.336223
# ...

# %%
month_data = handler.extract_month(data.copy(), 'Release Date')
print("\nExtracted Month Data:")
month_data
# Out:
# Extracted Month Data:
#      Movie Id Release Date    Rating  \
# 0   TOYHANVUR   1985-07-07  9.750176
# 1   CORCILSLF   1999-05-08  7.912876
# 2   UBWUVIHEL   1996-08-05  3.116053
# 3   CGHMHKJHH          NaT  8.811783
# 4   WMLWHTAMN          NaT  5.250991
# 5   REKCPGLOJ   2013-04-06  8.676586
# 6   GSDOQQRPD          NaT  9.191819
# 7   VMIYHZNZJ          NaT  9.459478
# 8   XVHGPYBBL          NaT  9.125866
# 9   NNZFDYZTH          NaT  9.232197
# 10  VZTEXQGBB          NaT  8.912548
# 11  XSPIAJYJM          NaT  8.561358
# 12  VFXKEREAP          NaT  7.742613
# 13  MCCASXIDK          NaT  9.727619
# 14  MTUOJCLUA   1989-03-03  6.913383
# 15  DBQTOTADE          NaT  8.276999
# 16  TKBEDDCMZ          NaT  7.591583
# 17  CDRJDLRCH          NaT  9.603778
# 18  WWAZEJQVI   1995-12-08  9.801080
# 19  IDFPFANWC          NaT  9.227341
# 20  QTIYFBNML   2005-02-08  7.858370
# 21  RQMTIJYHD          NaT  5.395632
# 22  GEGWEHHWS   2001-06-12  8.336223
# ...

# %%
day_data = handler.extract_day(data.copy(), 'Release Date')
print("\nExtracted Day Data:")
day_data
# Out:
# Extracted Day Data:
#      Movie Id Release Date    Rating  \
# 0   TOYHANVUR   1985-07-07  9.750176
# 1   CORCILSLF   1999-05-08  7.912876
# 2   UBWUVIHEL   1996-08-05  3.116053
# 3   CGHMHKJHH          NaT  8.811783
# 4   WMLWHTAMN          NaT  5.250991
# 5   REKCPGLOJ   2013-04-06  8.676586
# 6   GSDOQQRPD          NaT  9.191819
# 7   VMIYHZNZJ          NaT  9.459478
# 8   XVHGPYBBL          NaT  9.125866
# 9   NNZFDYZTH          NaT  9.232197
# 10  VZTEXQGBB          NaT  8.912548
# 11  XSPIAJYJM          NaT  8.561358
# 12  VFXKEREAP          NaT  7.742613
# 13  MCCASXIDK          NaT  9.727619
# 14  MTUOJCLUA   1989-03-03  6.913383
# 15  DBQTOTADE          NaT  8.276999
# 16  TKBEDDCMZ          NaT  7.591583
# 17  CDRJDLRCH          NaT  9.603778
# 18  WWAZEJQVI   1995-12-08  9.801080
# 19  IDFPFANWC          NaT  9.227341
# 20  QTIYFBNML   2005-02-08  7.858370
# 21  RQMTIJYHD          NaT  5.395632
# 22  GEGWEHHWS   2001-06-12  8.336223
# 23  QSUPSGILT   2002-04-02  7.216878
# ...

# %%
hour_data = handler.extract_hour(data.copy(), 'Release Date')
print("\nExtracted Hour Data:")
hour_data
# Out:
# Extracted Hour Data:
#      Movie Id Release Date    Rating  \
# 0   TOYHANVUR   1985-07-07  9.750176
# 1   CORCILSLF   1999-05-08  7.912876
# 2   UBWUVIHEL   1996-08-05  3.116053
# 3   CGHMHKJHH          NaT  8.811783
# 4   WMLWHTAMN          NaT  5.250991
# 5   REKCPGLOJ   2013-04-06  8.676586
# 6   GSDOQQRPD          NaT  9.191819
# 7   VMIYHZNZJ          NaT  9.459478
# 8   XVHGPYBBL          NaT  9.125866
# 9   NNZFDYZTH          NaT  9.232197
# 10  VZTEXQGBB          NaT  8.912548
# 11  XSPIAJYJM          NaT  8.561358
# 12  VFXKEREAP          NaT  7.742613
# 13  MCCASXIDK          NaT  9.727619
# 14  MTUOJCLUA   1989-03-03  6.913383
# 15  DBQTOTADE          NaT  8.276999
# 16  TKBEDDCMZ          NaT  7.591583
# 17  CDRJDLRCH          NaT  9.603778
# 18  WWAZEJQVI   1995-12-08  9.801080
# 19  IDFPFANWC          NaT  9.227341
# 20  QTIYFBNML   2005-02-08  7.858370
# 21  RQMTIJYHD          NaT  5.395632
# 22  GEGWEHHWS   2001-06-12  8.336223
# ...

# %%
minute_data = handler.extract_minute(data.copy(), 'Release Date')
print("\nExtracted Minute Data:")
minute_data
# Out:
# Extracted Minute Data:
#      Movie Id Release Date    Rating  \
# 0   TOYHANVUR   1985-07-07  9.750176
# 1   CORCILSLF   1999-05-08  7.912876
# 2   UBWUVIHEL   1996-08-05  3.116053
# 3   CGHMHKJHH          NaT  8.811783
# 4   WMLWHTAMN          NaT  5.250991
# 5   REKCPGLOJ   2013-04-06  8.676586
# 6   GSDOQQRPD          NaT  9.191819
# 7   VMIYHZNZJ          NaT  9.459478
# 8   XVHGPYBBL          NaT  9.125866
# 9   NNZFDYZTH          NaT  9.232197
# 10  VZTEXQGBB          NaT  8.912548
# 11  XSPIAJYJM          NaT  8.561358
# 12  VFXKEREAP          NaT  7.742613
# 13  MCCASXIDK          NaT  9.727619
# 14  MTUOJCLUA   1989-03-03  6.913383
# 15  DBQTOTADE          NaT  8.276999
# 16  TKBEDDCMZ          NaT  7.591583
# 17  CDRJDLRCH          NaT  9.603778
# 18  WWAZEJQVI   1995-12-08  9.801080
# 19  IDFPFANWC          NaT  9.227341
# 20  QTIYFBNML   2005-02-08  7.858370
# 21  RQMTIJYHD          NaT  5.395632
# 22  GEGWEHHWS   2001-06-12  8.336223
# ...

# %%
second_data = handler.extract_second(data.copy(), 'Release Date')
print("\nExtracted Second Data:")
second_data
# Out:
# Extracted Second Data:
#      Movie Id Release Date    Rating  \
# 0   TOYHANVUR   1985-07-07  9.750176
# 1   CORCILSLF   1999-05-08  7.912876
# 2   UBWUVIHEL   1996-08-05  3.116053
# 3   CGHMHKJHH          NaT  8.811783
# 4   WMLWHTAMN          NaT  5.250991
# 5   REKCPGLOJ   2013-04-06  8.676586
# 6   GSDOQQRPD          NaT  9.191819
# 7   VMIYHZNZJ          NaT  9.459478
# 8   XVHGPYBBL          NaT  9.125866
# 9   NNZFDYZTH          NaT  9.232197
# 10  VZTEXQGBB          NaT  8.912548
# 11  XSPIAJYJM          NaT  8.561358
# 12  VFXKEREAP          NaT  7.742613
# 13  MCCASXIDK          NaT  9.727619
# 14  MTUOJCLUA   1989-03-03  6.913383
# 15  DBQTOTADE          NaT  8.276999
# 16  TKBEDDCMZ          NaT  7.591583
# 17  CDRJDLRCH          NaT  9.603778
# 18  WWAZEJQVI   1995-12-08  9.801080
# 19  IDFPFANWC          NaT  9.227341
# 20  QTIYFBNML   2005-02-08  7.858370
# 21  RQMTIJYHD          NaT  5.395632
# 22  GEGWEHHWS   2001-06-12  8.336223
# ...

# %%
day_of_week_data = handler.extract_day_of_week(data.copy(), 'Release Date')
print("\nExtracted Day of Week Data:")
day_of_week_data
# Out:
# Extracted Day of Week Data:
#      Movie Id Release Date    Rating  \
# 0   TOYHANVUR   1985-07-07  9.750176
# 1   CORCILSLF   1999-05-08  7.912876
# 2   UBWUVIHEL   1996-08-05  3.116053
# 3   CGHMHKJHH          NaT  8.811783
# 4   WMLWHTAMN          NaT  5.250991
# 5   REKCPGLOJ   2013-04-06  8.676586
# 6   GSDOQQRPD          NaT  9.191819
# 7   VMIYHZNZJ          NaT  9.459478
# 8   XVHGPYBBL          NaT  9.125866
# 9   NNZFDYZTH          NaT  9.232197
# 10  VZTEXQGBB          NaT  8.912548
# 11  XSPIAJYJM          NaT  8.561358
# 12  VFXKEREAP          NaT  7.742613
# 13  MCCASXIDK          NaT  9.727619
# 14  MTUOJCLUA   1989-03-03  6.913383
# 15  DBQTOTADE          NaT  8.276999
# 16  TKBEDDCMZ          NaT  7.591583
# 17  CDRJDLRCH          NaT  9.603778
# 18  WWAZEJQVI   1995-12-08  9.801080
# 19  IDFPFANWC          NaT  9.227341
# 20  QTIYFBNML   2005-02-08  7.858370
# 21  RQMTIJYHD          NaT  5.395632
# 22  GEGWEHHWS   2001-06-12  8.336223
# ...

# %%
day_of_year_data = handler.extract_day_of_year(data.copy(), 'Release Date')
print("\nExtracted Day of Year Data:")
day_of_year_data
# Out:
# Extracted Day of Year Data:
#      Movie Id Release Date    Rating  \
# 0   TOYHANVUR   1985-07-07  9.750176
# 1   CORCILSLF   1999-05-08  7.912876
# 2   UBWUVIHEL   1996-08-05  3.116053
# 3   CGHMHKJHH          NaT  8.811783
# 4   WMLWHTAMN          NaT  5.250991
# 5   REKCPGLOJ   2013-04-06  8.676586
# 6   GSDOQQRPD          NaT  9.191819
# 7   VMIYHZNZJ          NaT  9.459478
# 8   XVHGPYBBL          NaT  9.125866
# 9   NNZFDYZTH          NaT  9.232197
# 10  VZTEXQGBB          NaT  8.912548
# 11  XSPIAJYJM          NaT  8.561358
# 12  VFXKEREAP          NaT  7.742613
# 13  MCCASXIDK          NaT  9.727619
# 14  MTUOJCLUA   1989-03-03  6.913383
# 15  DBQTOTADE          NaT  8.276999
# 16  TKBEDDCMZ          NaT  7.591583
# 17  CDRJDLRCH          NaT  9.603778
# 18  WWAZEJQVI   1995-12-08  9.801080
# 19  IDFPFANWC          NaT  9.227341
# 20  QTIYFBNML   2005-02-08  7.858370
# 21  RQMTIJYHD          NaT  5.395632
# 22  GEGWEHHWS   2001-06-12  8.336223
# ...

# %%
week_of_year_data = handler.extract_week_of_year(data.copy(), 'Release Date')
print("\nExtracted Week of Year Data:")
week_of_year_data
# Out:
# Extracted Week of Year Data:
#      Movie Id Release Date    Rating  \
# 0   TOYHANVUR   1985-07-07  9.750176
# 1   CORCILSLF   1999-05-08  7.912876
# 2   UBWUVIHEL   1996-08-05  3.116053
# 3   CGHMHKJHH          NaT  8.811783
# 4   WMLWHTAMN          NaT  5.250991
# 5   REKCPGLOJ   2013-04-06  8.676586
# 6   GSDOQQRPD          NaT  9.191819
# 7   VMIYHZNZJ          NaT  9.459478
# 8   XVHGPYBBL          NaT  9.125866
# 9   NNZFDYZTH          NaT  9.232197
# 10  VZTEXQGBB          NaT  8.912548
# 11  XSPIAJYJM          NaT  8.561358
# 12  VFXKEREAP          NaT  7.742613
# 13  MCCASXIDK          NaT  9.727619
# 14  MTUOJCLUA   1989-03-03  6.913383
# 15  DBQTOTADE          NaT  8.276999
# 16  TKBEDDCMZ          NaT  7.591583
# 17  CDRJDLRCH          NaT  9.603778
# 18  WWAZEJQVI   1995-12-08  9.801080
# 19  IDFPFANWC          NaT  9.227341
# 20  QTIYFBNML   2005-02-08  7.858370
# 21  RQMTIJYHD          NaT  5.395632
# 22  GEGWEHHWS   2001-06-12  8.336223
# ...

# %%
quarter_data = handler.extract_quarter(data.copy(), 'Release Date')
print("\nExtracted Quarter Data:")
quarter_data
# Out:
# Extracted Quarter Data:
#      Movie Id Release Date    Rating  \
# 0   TOYHANVUR   1985-07-07  9.750176
# 1   CORCILSLF   1999-05-08  7.912876
# 2   UBWUVIHEL   1996-08-05  3.116053
# 3   CGHMHKJHH          NaT  8.811783
# 4   WMLWHTAMN          NaT  5.250991
# 5   REKCPGLOJ   2013-04-06  8.676586
# 6   GSDOQQRPD          NaT  9.191819
# 7   VMIYHZNZJ          NaT  9.459478
# 8   XVHGPYBBL          NaT  9.125866
# 9   NNZFDYZTH          NaT  9.232197
# 10  VZTEXQGBB          NaT  8.912548
# 11  XSPIAJYJM          NaT  8.561358
# 12  VFXKEREAP          NaT  7.742613
# 13  MCCASXIDK          NaT  9.727619
# 14  MTUOJCLUA   1989-03-03  6.913383
# 15  DBQTOTADE          NaT  8.276999
# 16  TKBEDDCMZ          NaT  7.591583
# 17  CDRJDLRCH          NaT  9.603778
# 18  WWAZEJQVI   1995-12-08  9.801080
# 19  IDFPFANWC          NaT  9.227341
# 20  QTIYFBNML   2005-02-08  7.858370
# 21  RQMTIJYHD          NaT  5.395632
# 22  GEGWEHHWS   2001-06-12  8.336223
# ...

# %%
elapsed_data = pd.DataFrame({
    'Start Date': ['01/01/2020', '05/03/2020', '10/10/2020'],
    'End Date': ['01/01/2021', '05/03/2021', '10/10/2021']
})

elapsed_time_data = handler.extract_elapsed_time(elapsed_data.copy(), 'Start Date', 'End Date', 'Elapsed Time')
print("\nElapsed Time Data:")
elapsed_time_data[['Start Date', 'End Date', 'Elapsed Time']]
# Out:
# Elapsed Time Data:
#   Start Date   End Date  Elapsed Time
# 0 2020-01-01 2021-01-01    31622400.0
# 1 2020-05-03 2021-05-03    31536000.0
# 2 2020-10-10 2021-10-10    31536000.0

# %% [markdown]
# ##**Feature Engineer**

# %%
# !pip install --upgrade data-preprocessing-lib-byarat
# Out:
# ...
#   Attempting uninstall: data-preprocessing-lib-byarat
#     Found existing installation: data-preprocessing-lib-byarat 1.10.2
#     Uninstalling data-preprocessing-lib-byarat-1.10.2:
#       Successfully uninstalled data-preprocessing-lib-byarat-1.10.2
# ...

# %%
# !pip show data-preprocessing-lib-byarat
# Out:
# Name: data-preprocessing-lib-byarat
# Version: 1.10.3
# Summary: An easy peasy comprehensive library for data preprocessing tasks
# Home-page:
# Author: Mehdi Miraç ARAT, Latif Şimşek
# Author-email: mehdimirac.arat@stu.fsm.edu.tr, latif.simsek@stu.fsm.edu.tr
# License:
# Location: /usr/local/lib/python3.10/dist-packages
# Requires: beautifulsoup4, contractions, emoji, nltk, numpy, pandas, pyspellchecker, scikit-learn
# Required-by:

# %%
import pandas as pd
data = pd.read_csv('/content/synthetic_sample_data_minimal.csv')
sample = pd.DataFrame(data)
sample
# Out:
#      Movie Id            Genre Release Date    Rating  \
# 0   TOYHANVUR           Horror   07/07/1985  9.750176
# 1   CORCILSLF      Documentary   05/08/1999  7.912876
# 2   UBWUVIHEL        Adventure   08/05/1996  3.116053
# 3   CGHMHKJHH          Fantasy   21/07/2018  8.811783
# 4   WMLWHTAMN          Fantasy   28/10/2011  5.250991
# 5   REKCPGLOJ           Comedy   04/06/2013  8.676586
# 6   GSDOQQRPD          Western   25/12/1995  9.191819
# 7   VMIYHZNZJ        Adventure   23/03/2018  9.459478
# 8   XVHGPYBBL          Mystery   19/06/2002  9.125866
# 9   NNZFDYZTH          History   16/02/2019  9.232197
# 10  VZTEXQGBB           Comedy   22/01/2018  8.912548
# 11  XSPIAJYJM          Fantasy   19/11/1985  8.561358
# 12  VFXKEREAP          Fantasy   29/07/1992  7.742613
# 13  MCCASXIDK            Crime   26/12/2003  9.727619
# 14  MTUOJCLUA           Horror   03/03/1989  6.913383
# 15  DBQTOTADE            Drama   23/10/1990  8.276999
# ...

# %%
from data_preprocessing_lib_byarat import MissingValueHandler, OutlierHandler, Scaler, TextCleaner, FeatureEngineer, DataTypeConverter, CategoricalEncoder, DateTimeHandler

# %%
engineer = FeatureEngineer()

# %%
normalized_budget_data = engineer.normalize_budget_by_year_update(data.copy(), 'Budget in USD', 'Release Date')
print("Normalized Budget by Year Data:")
normalized_budget_data[['Release Date', 'Budget in USD', 'normalized_budget']]
# Out:
# Normalized Budget by Year Data:
#    Release Date  Budget in USD  normalized_budget
# 0    1985-07-07   1.035408e+07           1.570390
# 1    1999-08-05            NaN                NaN
# 2    1996-05-08   5.601372e+07           1.000000
# 3    2018-07-21   4.422451e+06           0.097575
# 4    2011-10-28            NaN                NaN
# 5    2013-06-04   2.406163e+07           1.000000
# 6    1995-12-25            NaN                NaN
# 7    2018-03-23   4.683286e+07           1.033304
# 8    2002-06-19   6.987464e+07           1.098016
# 9    2019-02-16   4.018517e+07           1.000000
# 10   2018-01-22   8.471490e+07           1.869120
# 11   1985-11-19   2.832553e+06           0.429610
# 12   1992-07-29   8.128408e+07           1.000000
# 13   2003-12-26   2.350500e+04           1.000000
# 14   1989-03-03   3.267364e+06           1.000000
# 15   1990-10-23   7.550006e+07           1.000000
# 16   2009-06-26   4.658762e+07           1.000000
# ...

# %%
date_parts_data = engineer.extract_date_parts_update(data.copy(), 'Release Date')
print("\nExtracted Date Parts Data:")
date_parts_data
# Out:
# Extracted Date Parts Data:
#      Movie Id            Genre Release Date    Rating  \
# 0   TOYHANVUR           Horror   1985-07-07  9.750176
# 1   CORCILSLF      Documentary   1999-08-05  7.912876
# 2   UBWUVIHEL        Adventure   1996-05-08  3.116053
# 3   CGHMHKJHH          Fantasy   2018-07-21  8.811783
# 4   WMLWHTAMN          Fantasy   2011-10-28  5.250991
# 5   REKCPGLOJ           Comedy   2013-06-04  8.676586
# 6   GSDOQQRPD          Western   1995-12-25  9.191819
# 7   VMIYHZNZJ        Adventure   2018-03-23  9.459478
# 8   XVHGPYBBL          Mystery   2002-06-19  9.125866
# 9   NNZFDYZTH          History   2019-02-16  9.232197
# 10  VZTEXQGBB           Comedy   2018-01-22  8.912548
# 11  XSPIAJYJM          Fantasy   1985-11-19  8.561358
# 12  VFXKEREAP          Fantasy   1992-07-29  7.742613
# 13  MCCASXIDK            Crime   2003-12-26  9.727619
# 14  MTUOJCLUA           Horror   1989-03-03  6.913383
# 15  DBQTOTADE            Drama   1990-10-23  8.276999
# ...

# %%
def sample_func(row):
    return row['Rating'] * 2

# %%
created_feature_data = engineer.create_feature(data.copy(), 'double_rating', sample_func)
print("\nCreated Feature Data:")
created_feature_data
# Out:
# Created Feature Data:
#      Movie Id            Genre Release Date    Rating  \
# 0   TOYHANVUR           Horror   07/07/1985  9.750176
# 1   CORCILSLF      Documentary   05/08/1999  7.912876
# 2   UBWUVIHEL        Adventure   08/05/1996  3.116053
# 3   CGHMHKJHH          Fantasy   21/07/2018  8.811783
# 4   WMLWHTAMN          Fantasy   28/10/2011  5.250991
# 5   REKCPGLOJ           Comedy   04/06/2013  8.676586
# 6   GSDOQQRPD          Western   25/12/1995  9.191819
# 7   VMIYHZNZJ        Adventure   23/03/2018  9.459478
# 8   XVHGPYBBL          Mystery   19/06/2002  9.125866
# 9   NNZFDYZTH          History   16/02/2019  9.232197
# 10  VZTEXQGBB           Comedy   22/01/2018  8.912548
# 11  XSPIAJYJM          Fantasy   19/11/1985  8.561358
# 12  VFXKEREAP          Fantasy   29/07/1992  7.742613
# 13  MCCASXIDK            Crime   26/12/2003  9.727619
# 14  MTUOJCLUA           Horror   03/03/1989  6.913383
# 15  DBQTOTADE            Drama   23/10/1990  8.276999
# ...

# %%
normalized_budget = engineer.normalize_budget(data.copy(), 'Budget in USD', 'Release Date')
print("\nNormalized Budget Data:")
normalized_budget
# Out:
# Normalized Budget Data:
#      Movie Id            Genre  Release Date    Rating  \
# 0   TOYHANVUR           Horror           NaN  9.750176
# 1   CORCILSLF      Documentary           NaN  7.912876
# 2   UBWUVIHEL        Adventure           NaN  3.116053
# 3   CGHMHKJHH          Fantasy           NaN  8.811783
# 4   WMLWHTAMN          Fantasy           NaN  5.250991
# 5   REKCPGLOJ           Comedy           NaN  8.676586
# 6   GSDOQQRPD          Western           NaN  9.191819
# 7   VMIYHZNZJ        Adventure           NaN  9.459478
# 8   XVHGPYBBL          Mystery           NaN  9.125866
# 9   NNZFDYZTH          History           NaN  9.232197
# 10  VZTEXQGBB           Comedy           NaN  8.912548
# 11  XSPIAJYJM          Fantasy           NaN  8.561358
# 12  VFXKEREAP          Fantasy           NaN  7.742613
# 13  MCCASXIDK            Crime           NaN  9.727619
# 14  MTUOJCLUA           Horror           NaN  6.913383
# 15  DBQTOTADE            Drama           NaN  8.276999
# ...

# %%
day_of_year_data = engineer.day_of_year_update(data.copy(), 'Release Date')
print("\nDay of Year Data:")
day_of_year_data
# Out:
# Day of Year Data:
#      Movie Id            Genre Release Date    Rating  \
# 0   TOYHANVUR           Horror   1985-07-07  9.750176
# 1   CORCILSLF      Documentary   1999-08-05  7.912876
# 2   UBWUVIHEL        Adventure   1996-05-08  3.116053
# 3   CGHMHKJHH          Fantasy   2018-07-21  8.811783
# 4   WMLWHTAMN          Fantasy   2011-10-28  5.250991
# 5   REKCPGLOJ           Comedy   2013-06-04  8.676586
# 6   GSDOQQRPD          Western   1995-12-25  9.191819
# 7   VMIYHZNZJ        Adventure   2018-03-23  9.459478
# 8   XVHGPYBBL          Mystery   2002-06-19  9.125866
# 9   NNZFDYZTH          History   2019-02-16  9.232197
# 10  VZTEXQGBB           Comedy   2018-01-22  8.912548
# 11  XSPIAJYJM          Fantasy   1985-11-19  8.561358
# 12  VFXKEREAP          Fantasy   1992-07-29  7.742613
# 13  MCCASXIDK            Crime   2003-12-26  9.727619
# 14  MTUOJCLUA           Horror   1989-03-03  6.913383
# 15  DBQTOTADE            Drama   1990-10-23  8.276999
# ...

# %%
conditional_data = engineer.conditional_feature(data.copy(), 'high_rating', lambda df: df['Rating'] > 8, 1, 0)
print("\nConditional Feature Data:")
conditional_data
# Out:
# Conditional Feature Data:
#      Movie Id            Genre Release Date    Rating  \
# 0   TOYHANVUR           Horror   07/07/1985  9.750176
# 1   CORCILSLF      Documentary   05/08/1999  7.912876
# 2   UBWUVIHEL        Adventure   08/05/1996  3.116053
# 3   CGHMHKJHH          Fantasy   21/07/2018  8.811783
# 4   WMLWHTAMN          Fantasy   28/10/2011  5.250991
# 5   REKCPGLOJ           Comedy   04/06/2013  8.676586
# 6   GSDOQQRPD          Western   25/12/1995  9.191819
# 7   VMIYHZNZJ        Adventure   23/03/2018  9.459478
# 8   XVHGPYBBL          Mystery   19/06/2002  9.125866
# 9   NNZFDYZTH          History   16/02/2019  9.232197
# 10  VZTEXQGBB           Comedy   22/01/2018  8.912548
# 11  XSPIAJYJM          Fantasy   19/11/1985  8.561358
# 12  VFXKEREAP          Fantasy   29/07/1992  7.742613
# 13  MCCASXIDK            Crime   26/12/2003  9.727619
# 14  MTUOJCLUA           Horror   03/03/1989  6.913383
# 15  DBQTOTADE            Drama   23/10/1990  8.276999
# ...

# %%
dummies_data = engineer.create_dummies(data.copy(), 'Genre')
print("\nCreate Dummies Data:")
dummies_data
# Out:
# Create Dummies Data:
#      Movie Id            Genre Release Date    Rating  \
# 0   TOYHANVUR           Horror   07/07/1985  9.750176
# 1   CORCILSLF      Documentary   05/08/1999  7.912876
# 2   UBWUVIHEL        Adventure   08/05/1996  3.116053
# 3   CGHMHKJHH          Fantasy   21/07/2018  8.811783
# 4   WMLWHTAMN          Fantasy   28/10/2011  5.250991
# 5   REKCPGLOJ           Comedy   04/06/2013  8.676586
# 6   GSDOQQRPD          Western   25/12/1995  9.191819
# 7   VMIYHZNZJ        Adventure   23/03/2018  9.459478
# 8   XVHGPYBBL          Mystery   19/06/2002  9.125866
# 9   NNZFDYZTH          History   16/02/2019  9.232197
# 10  VZTEXQGBB           Comedy   22/01/2018  8.912548
# 11  XSPIAJYJM          Fantasy   19/11/1985  8.561358
# 12  VFXKEREAP          Fantasy   29/07/1992  7.742613
# 13  MCCASXIDK            Crime   26/12/2003  9.727619
# 14  MTUOJCLUA           Horror   03/03/1989  6.913383
# 15  DBQTOTADE            Drama   23/10/1990  8.276999
# ...

# %%
log_transformed_data = engineer.log_transform(data.copy(), 'Rating')
print("\nLog Transformed Data:")
log_transformed_data
# Out:
# Log Transformed Data:
#      Movie Id            Genre Release Date    Rating  \
# 0   TOYHANVUR           Horror   07/07/1985  9.750176
# 1   CORCILSLF      Documentary   05/08/1999  7.912876
# 2   UBWUVIHEL        Adventure   08/05/1996  3.116053
# 3   CGHMHKJHH          Fantasy   21/07/2018  8.811783
# 4   WMLWHTAMN          Fantasy   28/10/2011  5.250991
# 5   REKCPGLOJ           Comedy   04/06/2013  8.676586
# 6   GSDOQQRPD          Western   25/12/1995  9.191819
# 7   VMIYHZNZJ        Adventure   23/03/2018  9.459478
# 8   XVHGPYBBL          Mystery   19/06/2002  9.125866
# 9   NNZFDYZTH          History   16/02/2019  9.232197
# 10  VZTEXQGBB           Comedy   22/01/2018  8.912548
# 11  XSPIAJYJM          Fantasy   19/11/1985  8.561358
# 12  VFXKEREAP          Fantasy   29/07/1992  7.742613
# 13  MCCASXIDK            Crime   26/12/2003  9.727619
# 14  MTUOJCLUA           Horror   03/03/1989  6.913383
# 15  DBQTOTADE            Drama   23/10/1990  8.276999
# ...

# %%
interaction_data = engineer.interaction_terms(data.copy(), ['Rating', 'Awards'])
print("\nInteraction Terms Data:")
interaction_data
# Out:
# Interaction Terms Data:
#      Movie Id            Genre Release Date    Rating  \
# 0   TOYHANVUR           Horror   07/07/1985  9.750176
# 1   CORCILSLF      Documentary   05/08/1999  7.912876
# 2   UBWUVIHEL        Adventure   08/05/1996  3.116053
# 3   CGHMHKJHH          Fantasy   21/07/2018  8.811783
# 4   WMLWHTAMN          Fantasy   28/10/2011  5.250991
# 5   REKCPGLOJ           Comedy   04/06/2013  8.676586
# 6   GSDOQQRPD          Western   25/12/1995  9.191819
# 7   VMIYHZNZJ        Adventure   23/03/2018  9.459478
# 8   XVHGPYBBL          Mystery   19/06/2002  9.125866
# 9   NNZFDYZTH          History   16/02/2019  9.232197
# 10  VZTEXQGBB           Comedy   22/01/2018  8.912548
# 11  XSPIAJYJM          Fantasy   19/11/1985  8.561358
# 12  VFXKEREAP          Fantasy   29/07/1992  7.742613
# 13  MCCASXIDK            Crime   26/12/2003  9.727619
# 14  MTUOJCLUA           Horror   03/03/1989  6.913383
# 15  DBQTOTADE            Drama   23/10/1990  8.276999
# ...

# %%
polynomial_data = engineer.polynomial_features(data.copy(), 'Rating', degree=3)
print("\nPolynomial Features Data:")
polynomial_data
# Out:
# Polynomial Features Data:
#      Movie Id            Genre Release Date    Rating  \
# 0   TOYHANVUR           Horror   07/07/1985  9.750176
# 1   CORCILSLF      Documentary   05/08/1999  7.912876
# 2   UBWUVIHEL        Adventure   08/05/1996  3.116053
# 3   CGHMHKJHH          Fantasy   21/07/2018  8.811783
# 4   WMLWHTAMN          Fantasy   28/10/2011  5.250991
# 5   REKCPGLOJ           Comedy   04/06/2013  8.676586
# 6   GSDOQQRPD          Western   25/12/1995  9.191819
# 7   VMIYHZNZJ        Adventure   23/03/2018  9.459478
# 8   XVHGPYBBL          Mystery   19/06/2002  9.125866
# 9   NNZFDYZTH          History   16/02/2019  9.232197
# 10  VZTEXQGBB           Comedy   22/01/2018  8.912548
# 11  XSPIAJYJM          Fantasy   19/11/1985  8.561358
# 12  VFXKEREAP          Fantasy   29/07/1992  7.742613
# 13  MCCASXIDK            Crime   26/12/2003  9.727619
# 14  MTUOJCLUA           Horror   03/03/1989  6.913383
# 15  DBQTOTADE            Drama   23/10/1990  8.276999
# ...

# %%
moving_avg_data = engineer.moving_average(data.copy(), 'Rating', window=3)
print("\nMoving Average Data:")
moving_avg_data
# Out:
# Moving Average Data:
#      Movie Id            Genre Release Date    Rating  \
# 0   TOYHANVUR           Horror   07/07/1985  9.750176
# 1   CORCILSLF      Documentary   05/08/1999  7.912876
# 2   UBWUVIHEL        Adventure   08/05/1996  3.116053
# 3   CGHMHKJHH          Fantasy   21/07/2018  8.811783
# 4   WMLWHTAMN          Fantasy   28/10/2011  5.250991
# 5   REKCPGLOJ           Comedy   04/06/2013  8.676586
# 6   GSDOQQRPD          Western   25/12/1995  9.191819
# 7   VMIYHZNZJ        Adventure   23/03/2018  9.459478
# 8   XVHGPYBBL          Mystery   19/06/2002  9.125866
# 9   NNZFDYZTH          History   16/02/2019  9.232197
# 10  VZTEXQGBB           Comedy   22/01/2018  8.912548
# 11  XSPIAJYJM          Fantasy   19/11/1985  8.561358
# 12  VFXKEREAP          Fantasy   29/07/1992  7.742613
# 13  MCCASXIDK            Crime   26/12/2003  9.727619
# 14  MTUOJCLUA           Horror   03/03/1989  6.913383
# 15  DBQTOTADE            Drama   23/10/1990  8.276999
# ...

# %% [markdown]
# ##**Missing Value Handler**

# %%
# !pip install --upgrade data-preprocessing-lib-byarat
# !pip show data-preprocessing-lib-byarat
# Out:
# ...
# Name: data-preprocessing-lib-byarat
# Version: 1.10.5
# Summary: An easy peasy comprehensive library for data preprocessing tasks
# Home-page:
# Author: Mehdi Miraç ARAT, Latif Şimşek
# Author-email: mehdimirac.arat@stu.fsm.edu.tr, latif.simsek@stu.fsm.edu.tr
# License:
# Location: /usr/local/lib/python3.10/dist-packages
# Requires: beautifulsoup4, contractions, emoji, nltk, numpy, pandas, pyspellchecker, scikit-learn
# Required-by:

# %%
import pandas as pd
data = pd.read_csv('/content/synthetic_sample_data_minimal.csv')
sample = pd.DataFrame(data)
sample
# Out:
#      Movie Id            Genre Release Date    Rating  \
# 0   TOYHANVUR           Horror   07/07/1985  9.750176
# 1   CORCILSLF      Documentary   05/08/1999  7.912876
# 2   UBWUVIHEL        Adventure   08/05/1996  3.116053
# 3   CGHMHKJHH          Fantasy   21/07/2018  8.811783
# 4   WMLWHTAMN          Fantasy   28/10/2011  5.250991
# 5   REKCPGLOJ           Comedy   04/06/2013  8.676586
# 6   GSDOQQRPD          Western   25/12/1995  9.191819
# 7   VMIYHZNZJ        Adventure   23/03/2018  9.459478
# 8   XVHGPYBBL          Mystery   19/06/2002  9.125866
# 9   NNZFDYZTH          History   16/02/2019  9.232197
# 10  VZTEXQGBB           Comedy   22/01/2018  8.912548
# 11  XSPIAJYJM          Fantasy   19/11/1985  8.561358
# 12  VFXKEREAP          Fantasy   29/07/1992  7.742613
# 13  MCCASXIDK            Crime   26/12/2003  9.727619
# 14  MTUOJCLUA           Horror   03/03/1989  6.913383
# 15  DBQTOTADE            Drama   23/10/1990  8.276999
# ...

# %%
from data_preprocessing_lib_byarat import MissingValueHandler, OutlierHandler, Scaler, TextCleaner, FeatureEngineer, DataTypeConverter, CategoricalEncoder, DateTimeHandler

# %%
handler = MissingValueHandler()

# %%
imputed_mean_data = handler.impute_with_mean(data.copy(), 'Budget in USD')
print("Imputed without Mean Data:")
data[['Budget in USD']]
# Out:
# Imputed without Mean Data:
#     Budget in USD
# 0    1.035408e+07
# 1             NaN
# 2    5.601372e+07
# 3    4.422451e+06
# 4             NaN
# 5    2.406163e+07
# 6             NaN
# 7    4.683286e+07
# 8    6.987464e+07
# 9    4.018517e+07
# 10   8.471490e+07
# 11   2.832553e+06
# 12   8.128408e+07
# 13   2.350500e+04
# 14   3.267364e+06
# 15   7.550006e+07
# 16   4.658762e+07
# 17   1.394423e+06
# 18   9.737322e+06
# 19   1.290734e+07
# 20   3.478010e+07
# 21   8.351821e+07
# 22   3.610468e+07
# 23   5.739973e+07
# 24   8.872575e+07
# 25   2.925571e+07
# 26            NaN
# 27   7.847867e+07
# 28            NaN

# %%
print("Imputed with Mean Data:")
imputed_mean_data[['Budget in USD']]
# Out:
# Imputed with Mean Data:
#     Budget in USD
# 0    1.035408e+07
# 1    4.076069e+07
# 2    5.601372e+07
# 3    4.422451e+06
# 4    4.076069e+07
# 5    2.406163e+07
# 6    4.076069e+07
# 7    4.683286e+07
# 8    6.987464e+07
# 9    4.018517e+07
# 10   8.471490e+07
# 11   2.832553e+06
# 12   8.128408e+07
# 13   2.350500e+04
# 14   3.267364e+06
# 15   7.550006e+07
# 16   4.658762e+07
# 17   1.394423e+06
# 18   9.737322e+06
# 19   1.290734e+07
# 20   3.478010e+07
# 21   8.351821e+07
# 22   3.610468e+07
# 23   5.739973e+07
# 24   8.872575e+07
# 25   2.925571e+07
# 26   4.076069e+07
# 27   7.847867e+07
# 28   4.076069e+07

# %%
imputed_median_data = handler.impute_with_median(data.copy(), 'Budget in USD')
print("\nImputed with Median Data:")
imputed_median_data[['Budget in USD']]
# Out:
# Imputed with Median Data:
#     Budget in USD
# 0    1.035408e+07
# 1    3.814493e+07
# 2    5.601372e+07
# 3    4.422451e+06
# 4    3.814493e+07
# 5    2.406163e+07
# 6    3.814493e+07
# 7    4.683286e+07
# 8    6.987464e+07
# 9    4.018517e+07
# 10   8.471490e+07
# 11   2.832553e+06
# 12   8.128408e+07
# 13   2.350500e+04
# 14   3.267364e+06
# 15   7.550006e+07
# 16   4.658762e+07
# 17   1.394423e+06
# 18   9.737322e+06
# 19   1.290734e+07
# 20   3.478010e+07
# 21   8.351821e+07
# 22   3.610468e+07
# 23   5.739973e+07
# 24   8.872575e+07
# 25   2.925571e+07
# 26   3.814493e+07
# 27   7.847867e+07
# 28   3.814493e+07

# %%
print("\nImputed without Median Data:")
data[['Budget in USD']]
# Out:
# Imputed without Median Data:
#     Budget in USD
# 0    1.035408e+07
# 1             NaN
# 2    5.601372e+07
# 3    4.422451e+06
# 4             NaN
# 5    2.406163e+07
# 6             NaN
# 7    4.683286e+07
# 8    6.987464e+07
# 9    4.018517e+07
# 10   8.471490e+07
# 11   2.832553e+06
# 12   8.128408e+07
# 13   2.350500e+04
# 14   3.267364e+06
# 15   7.550006e+07
# 16   4.658762e+07
# 17   1.394423e+06
# 18   9.737322e+06
# 19   1.290734e+07
# 20   3.478010e+07
# 21   8.351821e+07
# 22   3.610468e+07
# 23   5.739973e+07
# 24   8.872575e+07
# 25   2.925571e+07
# 26            NaN
# 27   7.847867e+07
# 28            NaN

# %%
imputed_constant_data = handler.impute_with_constant(data.copy(), 'Budget in USD', 1000000)
print("\nImputed with Constant Data:")
imputed_constant_data[['Budget in USD']]
# Out:
# Imputed with Constant Data:
#     Budget in USD
# 0    1.035408e+07
# 1    1.000000e+06
# 2    5.601372e+07
# 3    4.422451e+06
# 4    1.000000e+06
# 5    2.406163e+07
# 6    1.000000e+06
# 7    4.683286e+07
# 8    6.987464e+07
# 9    4.018517e+07
# 10   8.471490e+07
# 11   2.832553e+06
# 12   8.128408e+07
# 13   2.350500e+04
# 14   3.267364e+06
# 15   7.550006e+07
# 16   4.658762e+07
# 17   1.394423e+06
# 18   9.737322e+06
# 19   1.290734e+07
# 20   3.478010e+07
# 21   8.351821e+07
# 22   3.610468e+07
# 23   5.739973e+07
# 24   8.872575e+07
# 25   2.925571e+07
# 26   1.000000e+06
# 27   7.847867e+07
# 28   1.000000e+06

# %%
print("\nDropped Without Missing Data:")
data[['Budget in USD']]
# Out:
# Dropped Without Missing Data:
#     Budget in USD
# 0    1.035408e+07
# 1             NaN
# 2    5.601372e+07
# 3    4.422451e+06
# 4             NaN
# 5    2.406163e+07
# 6             NaN
# 7    4.683286e+07
# 8    6.987464e+07
# 9    4.018517e+07
# 10   8.471490e+07
# 11   2.832553e+06
# 12   8.128408e+07
# 13   2.350500e+04
# 14   3.267364e+06
# 15   7.550006e+07
# 16   4.658762e+07
# 17   1.394423e+06
# 18   9.737322e+06
# 19   1.290734e+07
# 20   3.478010e+07
# 21   8.351821e+07
# 22   3.610468e+07
# 23   5.739973e+07
# 24   8.872575e+07
# 25   2.925571e+07
# 26            NaN
# 27   7.847867e+07
# 28            NaN

# %%
dropped_missing_data = handler.drop_missing(data.copy(), 'Budget in USD')
print("\nDropped Missing Data:")
dropped_missing_data[['Budget in USD']]
# Out:
# Dropped Missing Data:
#     Budget in USD
# 0    1.035408e+07
# 2    5.601372e+07
# 3    4.422451e+06
# 5    2.406163e+07
# 7    4.683286e+07
# 8    6.987464e+07
# 9    4.018517e+07
# 10   8.471490e+07
# 11   2.832553e+06
# 12   8.128408e+07
# 13   2.350500e+04
# 14   3.267364e+06
# 15   7.550006e+07
# 16   4.658762e+07
# 17   1.394423e+06
# 18   9.737322e+06
# 19   1.290734e+07
# 20   3.478010e+07
# 21   8.351821e+07
# 22   3.610468e+07
# 23   5.739973e+07
# 24   8.872575e+07
# 25   2.925571e+07
# 27   7.847867e+07

# %%
data[['Budget in USD']]
# Out:
#     Budget in USD
# 0    1.035408e+07
# 1             NaN
# 2    5.601372e+07
# 3    4.422451e+06
# 4             NaN
# 5    2.406163e+07
# 6             NaN
# 7    4.683286e+07
# 8    6.987464e+07
# 9    4.018517e+07
# 10   8.471490e+07
# 11   2.832553e+06
# 12   8.128408e+07
# 13   2.350500e+04
# 14   3.267364e+06
# 15   7.550006e+07
# 16   4.658762e+07
# 17   1.394423e+06
# 18   9.737322e+06
# 19   1.290734e+07
# 20   3.478010e+07
# 21   8.351821e+07
# 22   3.610468e+07
# 23   5.739973e+07
# 24   8.872575e+07
# 25   2.925571e+07
# 26            NaN
# 27   7.847867e+07
# 28            NaN

# %%
imputed_mode_data = handler.impute_with_mode(data.copy(), 'Budget in USD')
print("\nImputed with Mode Data:")
imputed_mode_data[['Budget in USD']]
# Out:
# Imputed with Mode Data:
#     Budget in USD
# 0    1.035408e+07
# 1    2.350500e+04
# 2    5.601372e+07
# 3    4.422451e+06
# 4    2.350500e+04
# 5    2.406163e+07
# 6    2.350500e+04
# 7    4.683286e+07
# 8    6.987464e+07
# 9    4.018517e+07
# 10   8.471490e+07
# 11   2.832553e+06
# 12   8.128408e+07
# 13   2.350500e+04
# 14   3.267364e+06
# 15   7.550006e+07
# 16   4.658762e+07
# 17   1.394423e+06
# 18   9.737322e+06
# 19   1.290734e+07
# 20   3.478010e+07
# 21   8.351821e+07
# 22   3.610468e+07
# 23   5.739973e+07
# 24   8.872575e+07
# 25   2.925571e+07
# 26   2.350500e+04
# 27   7.847867e+07
# 28   2.350500e+04

# %%
data[['Budget in USD']]
# Out:
#     Budget in USD
# 0    1.035408e+07
# 1             NaN
# 2    5.601372e+07
# 3    4.422451e+06
# 4             NaN
# 5    2.406163e+07
# 6             NaN
# 7    4.683286e+07
# 8    6.987464e+07
# 9    4.018517e+07
# 10   8.471490e+07
# 11   2.832553e+06
# 12   8.128408e+07
# 13   2.350500e+04
# 14   3.267364e+06
# 15   7.550006e+07
# 16   4.658762e+07
# 17   1.394423e+06
# 18   9.737322e+06
# 19   1.290734e+07
# 20   3.478010e+07
# 21   8.351821e+07
# 22   3.610468e+07
# 23   5.739973e+07
# 24   8.872575e+07
# 25   2.925571e+07
# 26            NaN
# 27   7.847867e+07
# 28            NaN

# %%
forward_filled_data = handler.forward_fill(data.copy(), 'Budget in USD')
print("\nForward Fill Data:")
forward_filled_data[['Budget in USD']]
# Out:
# Forward Fill Data:
#     Budget in USD
# 0    1.035408e+07
# 1    1.035408e+07
# 2    5.601372e+07
# 3    4.422451e+06
# 4    4.422451e+06
# 5    2.406163e+07
# 6    2.406163e+07
# 7    4.683286e+07
# 8    6.987464e+07
# 9    4.018517e+07
# 10   8.471490e+07
# 11   2.832553e+06
# 12   8.128408e+07
# 13   2.350500e+04
# 14   3.267364e+06
# 15   7.550006e+07
# 16   4.658762e+07
# 17   1.394423e+06
# 18   9.737322e+06
# 19   1.290734e+07
# 20   3.478010e+07
# 21   8.351821e+07
# 22   3.610468e+07
# 23   5.739973e+07
# 24   8.872575e+07
# 25   2.925571e+07
# 26   2.925571e+07
# 27   7.847867e+07
# 28   7.847867e+07

# %%
backward_filled_data = handler.backward_fill(data.copy(), 'Budget in USD')
print("\nBackward Fill Data:")
backward_filled_data[['Budget in USD']]
# Out:
# Backward Fill Data:
#     Budget in USD
# 0    1.035408e+07
# 1    5.601372e+07
# 2    5.601372e+07
# 3    4.422451e+06
# 4    2.406163e+07
# 5    2.406163e+07
# 6    4.683286e+07
# 7    4.683286e+07
# 8    6.987464e+07
# 9    4.018517e+07
# 10   8.471490e+07
# 11   2.832553e+06
# 12   8.128408e+07
# 13   2.350500e+04
# 14   3.267364e+06
# 15   7.550006e+07
# 16   4.658762e+07
# 17   1.394423e+06
# 18   9.737322e+06
# 19   1.290734e+07
# 20   3.478010e+07
# 21   8.351821e+07
# 22   3.610468e+07
# 23   5.739973e+07
# 24   8.872575e+07
# 25   2.925571e+07
# 26   7.847867e+07
# 27   7.847867e+07
# 28            NaN

# %%
knn_imputed_data = handler.impute_knn(data.copy(), ['Budget in USD', 'Rating'])
print("\nKNN Imputed Data:")
knn_imputed_data[['Budget in USD', 'Rating']]
# Out:
# KNN Imputed Data:
#     Budget in USD    Rating
# 0    1.035408e+07  9.750176
# 1    4.031781e+07  7.912876
# 2    5.601372e+07  3.116053
# 3    4.422451e+06  8.811783
# 4    4.935733e+07  5.250991
# 5    2.406163e+07  8.676586
# 6    5.342596e+07  9.191819
# 7    4.683286e+07  9.459478
# 8    6.987464e+07  9.125866
# 9    4.018517e+07  9.232197
# 10   8.471490e+07  8.912548
# 11   2.832553e+06  8.561358
# 12   8.128408e+07  7.742613
# 13   2.350500e+04  9.727619
# 14   3.267364e+06  6.913383
# 15   7.550006e+07  8.276999
# 16   4.658762e+07  7.591583
# 17   1.394423e+06  9.603778
# 18   9.737322e+06  9.801080
# 19   1.290734e+07  9.227341
# 20   3.478010e+07  7.858370
# 21   8.351821e+07  5.395632
# 22   3.610468e+07  8.336223
# 23   5.739973e+07  7.216878
# 24   8.872575e+07  9.397201
# 25   2.925571e+07  9.852601
# 26   7.239583e+07  9.090585
# 27   7.847867e+07  9.592543
# 28   5.441140e+07  5.720490

# %%
data[['Budget in USD', 'Rating']]
# Out:
#     Budget in USD    Rating
# 0    1.035408e+07  9.750176
# 1             NaN  7.912876
# 2    5.601372e+07  3.116053
# 3    4.422451e+06  8.811783
# 4             NaN  5.250991
# 5    2.406163e+07  8.676586
# 6             NaN  9.191819
# 7    4.683286e+07  9.459478
# 8    6.987464e+07  9.125866
# 9    4.018517e+07  9.232197
# 10   8.471490e+07  8.912548
# 11   2.832553e+06  8.561358
# 12   8.128408e+07  7.742613
# 13   2.350500e+04  9.727619
# 14   3.267364e+06  6.913383
# 15   7.550006e+07  8.276999
# 16   4.658762e+07  7.591583
# 17   1.394423e+06  9.603778
# 18   9.737322e+06  9.801080
# 19   1.290734e+07  9.227341
# 20   3.478010e+07  7.858370
# 21   8.351821e+07  5.395632
# 22   3.610468e+07  8.336223
# 23   5.739973e+07  7.216878
# 24   8.872575e+07  9.397201
# 25   2.925571e+07  9.852601
# 26            NaN  9.090585
# 27   7.847867e+07  9.592543
# 28            NaN  5.720490

# %%
marked_missing_data = handler.mark_missing(data.copy(), 'Budget in USD')
print("\nMarked Missing Data:")
marked_missing_data[['Budget in USD', 'Budget in USD_missing']]
# Out:
# Marked Missing Data:
#     Budget in USD  Budget in USD_missing
# 0    1.035408e+07                  False
# 1             NaN                   True
# 2    5.601372e+07                  False
# 3    4.422451e+06                  False
# 4             NaN                   True
# 5    2.406163e+07                  False
# 6             NaN                   True
# 7    4.683286e+07                  False
# 8    6.987464e+07                  False
# 9    4.018517e+07                  False
# 10   8.471490e+07                  False
# 11   2.832553e+06                  False
# 12   8.128408e+07                  False
# 13   2.350500e+04                  False
# 14   3.267364e+06                  False
# 15   7.550006e+07                  False
# 16   4.658762e+07                  False
# 17   1.394423e+06                  False
# 18   9.737322e+06                  False
# 19   1.290734e+07                  False
# 20   3.478010e+07                  False
# ...

# %%
data[['Rating', 'Budget in USD']]
# Out:
#       Rating  Budget in USD
# 0   9.750176   1.035408e+07
# 1   7.912876            NaN
# 2   3.116053   5.601372e+07
# 3   8.811783   4.422451e+06
# 4   5.250991            NaN
# 5   8.676586   2.406163e+07
# 6   9.191819            NaN
# 7   9.459478   4.683286e+07
# 8   9.125866   6.987464e+07
# 9   9.232197   4.018517e+07
# 10  8.912548   8.471490e+07
# 11  8.561358   2.832553e+06
# 12  7.742613   8.128408e+07
# 13  9.727619   2.350500e+04
# 14  6.913383   3.267364e+06
# 15  8.276999   7.550006e+07
# 16  7.591583   4.658762e+07
# 17  9.603778   1.394423e+06
# 18  9.801080   9.737322e+06
# 19  9.227341   1.290734e+07
# 20  7.858370   3.478010e+07
# 21  5.395632   8.351821e+07
# 22  8.336223   3.610468e+07
# 23  7.216878   5.739973e+07
# 24  9.397201   8.872575e+07
# 25  9.852601   2.925571e+07
# 26  9.090585            NaN
# 27  9.592543   7.847867e+07
# 28  5.720490            NaN

# %%
group_mean_imputed_data = handler.impute_group_mean(data.copy(), 'Rating', 'Budget in USD')
print("\nGroup Mean Imputed Data:")
group_mean_imputed_data[['Rating', 'Budget in USD']]
# Out:
# Group Mean Imputed Data:
#       Rating  Budget in USD
# 0   9.750176   1.035408e+07
# 1   7.912876            NaN
# 2   3.116053   5.601372e+07
# 3   8.811783   4.422451e+06
# 4   5.250991            NaN
# 5   8.676586   2.406163e+07
# 6   9.191819            NaN
# 7   9.459478   4.683286e+07
# 8   9.125866   6.987464e+07
# 9   9.232197   4.018517e+07
# 10  8.912548   8.471490e+07
# 11  8.561358   2.832553e+06
# 12  7.742613   8.128408e+07
# 13  9.727619   2.350500e+04
# 14  6.913383   3.267364e+06
# 15  8.276999   7.550006e+07
# 16  7.591583   4.658762e+07
# 17  9.603778   1.394423e+06
# 18  9.801080   9.737322e+06
# 19  9.227341   1.290734e+07
# 20  7.858370   3.478010e+07
# 21  5.395632   8.351821e+07
# 22  8.336223   3.610468e+07
# 23  7.216878   5.739973e+07
# 24  9.397201   8.872575e+07
# 25  9.852601   2.925571e+07
# 26  9.090585            NaN
# 27  9.592543   7.847867e+07
# 28  5.720490            NaN

# %%
group_median_imputed_data = handler.impute_group_median_update (data.copy(), 'Budget in USD', 'Rating')
print("\nGroup Median Imputed Data:")
group_median_imputed_data[['Rating', 'Budget in USD']]
# Out:
# Group Medians:
# Budget in USD
# 2.350500e+04    9.727619
# 1.394423e+06    9.603778
# 2.832553e+06    8.561358
# 3.267364e+06    6.913383
# 4.422451e+06    8.811783
# 9.737322e+06    9.801080
# 1.035408e+07    9.750176
# 1.290734e+07    9.227341
# 2.406163e+07    8.676586
# 2.925571e+07    9.852601
# 3.478010e+07    7.858370
# 3.610468e+07    8.336223
# 4.018517e+07    9.232197
# 4.658762e+07    7.591583
# 4.683286e+07    9.459478
# 5.601372e+07    3.116053
# 5.739973e+07    7.216878
# 6.987464e+07    9.125866
# 7.550006e+07    8.276999
# 7.847867e+07    9.592543
# 8.128408e+07    7.742613
# 8.351821e+07    5.395632
# 8.471490e+07    8.912548
# 8.872575e+07    9.397201
# Name: Rating, dtype: float64
#
# Group Median Imputed Data:
#       Rating  Budget in USD
# 0   9.750176   1.035408e+07
# 1        NaN            NaN
# 2   3.116053   5.601372e+07
# 3   8.811783   4.422451e+06
# 4        NaN            NaN
# 5   8.676586   2.406163e+07
# 6        NaN            NaN
# ...

# %% [markdown]
# ##**Outlier Handler**

# %%
outhandler = OutlierHandler()

# %%
print("IQR Outlier Detection:")
iqr_outliers = outhandler.detect_outliers_iqr(data.copy(), 'Rating')
iqr_outliers
# Out:
# IQR Outlier Detection:
#     Movie Id      Genre Release Date    Rating  \
# 2  UBWUVIHEL  Adventure   08/05/1996  3.116053
# 4  WMLWHTAMN    Fantasy   28/10/2011  5.250991
#
#                                              Summary Shooting Location  \
# 2  A lost civilization is rediscovered deep withi...            Sydney
# 4  A young inventor builds a time machine and emb...            Sydney
#
#    Budget in USD  Awards  Popular
# 2    56013723.35       0        0
# 4            NaN       0        0

# %%
print("\nZ-Score Outlier Detection:")
z_score_outliers = outhandler.detect_outliers_z_score(data.copy(), 'Rating')
z_score_outliers
# Out:
# Z-Score Outlier Detection:
#     Movie Id      Genre Release Date    Rating  \
# 2  UBWUVIHEL  Adventure   08/05/1996  3.116053
#
#                                              Summary Shooting Location  \
# 2  A lost civilization is rediscovered deep withi...            Sydney
#
#    Budget in USD  Awards  Popular
# 2    56013723.35       0        0

# %%
print("\nMAD Outlier Detection:")
mad_outliers = outhandler.detect_outliers_mad(data.copy(), 'Rating')
mad_outliers
# Out:
# MAD Outlier Detection:
#     Movie Id      Genre Release Date    Rating  \
# 2  UBWUVIHEL  Adventure   08/05/1996  3.116053
# 4  WMLWHTAMN    Fantasy   28/10/2011  5.250991
#
#                                              Summary Shooting Location  \
# 2  A lost civilization is rediscovered deep withi...            Sydney
# 4  A young inventor builds a time machine and emb...            Sydney
#
#    Budget in USD  Awards  Popular
# 2    56013723.35       0        0
# 4            NaN       0        0

# %%
print("\nMahalanobis Outlier Detection:")
mahalanobis_outliers = outhandler.detect_outliers_mahalanobis(data.copy(), ['Rating'])
mahalanobis_outliers
# Out:
# Mahalanobis Outlier Detection:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-31-6b26b89baf2a> in <cell line: 2>()
#       1 print("\nMahalanobis Outlier Detection:")
# ----> 2 mahalanobis_outliers = outhandler.detect_outliers_mahalanobis(data.copy(), ['Rating'])
#       3 mahalanobis_outliers
#
# /usr/local/lib/python3.10/dist-packages/data_preprocessing_lib_byarat/outlier_handler.py in detect_outliers_mahalanobis(df, columns, threshold)
#      91         x_mean = np.mean(x, axis=0)
#      92         x_cov = np.cov(x, rowvar=False)
# ---> 93         x_inv_cov = np.linalg.inv(x_cov)
#      94         x_diff = x - x_mean
#      95         mahalanobis_dist = np.sqrt(np.sum(np.dot(x_diff, x_inv_cov) * x_diff, axis=1))
#
# /usr/local/lib/python3.10/dist-packages/numpy/linalg/linalg.py in inv(a)
#     553     """
#     554     a, wrap = _makearray(a)
# ...

# %%
print("\nTukey's Fences Outlier Detection:")
tukeys_fences_outliers = outhandler.detect_outliers_tukeys_fences(data.copy(), 'Rating')
tukeys_fences_outliers
# Out:
# Tukey's Fences Outlier Detection:
#     Movie Id      Genre Release Date    Rating  \
# 2  UBWUVIHEL  Adventure   08/05/1996  3.116053
# 4  WMLWHTAMN    Fantasy   28/10/2011  5.250991
#
#                                              Summary Shooting Location  \
# 2  A lost civilization is rediscovered deep withi...            Sydney
# 4  A young inventor builds a time machine and emb...            Sydney
#
#    Budget in USD  Awards  Popular
# 2    56013723.35       0        0
# 4            NaN       0        0

# %%
print("\nIsolation Forest Outlier Detection:")
isolation_forest_outliers = outhandler.detect_outliers_isolation_forest(data.copy(), 'Rating')

isolation_forest_outliers
# Out:
# Isolation Forest Outlier Detection:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
#      Movie Id      Genre Release Date    Rating  \
# 2   UBWUVIHEL  Adventure   08/05/1996  3.116053
# 4   WMLWHTAMN    Fantasy   28/10/2011  5.250991
# 28  ZZIBKYJID   Thriller   02/05/2019  5.720490
#
#                                               Summary Shooting Location  \
# 2   A lost civilization is rediscovered deep withi...            Sydney
# 4   A young inventor builds a time machine and emb...            Sydney
# 28  A suspenseful thriller about a family trapped ...          New York
#
#     Budget in USD  Awards  Popular
# 2     56013723.35       0        0
# 4             NaN       0        0
# 28            NaN       0        0

# %%
print("\nLocal Outlier Factor Detection:")
lof_outliers = outhandler.detect_outliers_local_outlier_factor(data.copy(), 'Rating')
lof_outliers
# Out:
# Local Outlier Factor Detection:
#      Movie Id        Genre Release Date    Rating  \
# 2   UBWUVIHEL    Adventure   08/05/1996  3.116053
# 4   WMLWHTAMN      Fantasy   28/10/2011  5.250991
# 21  RQMTIJYHD  Documentary   15/08/1997  5.395632
#
#                                               Summary Shooting Location  \
# 2   A lost civilization is rediscovered deep withi...            Sydney
# 4   A young inventor builds a time machine and emb...            Sydney
# 21  A historical drama depicting a pivotal moment ...             Tokyo
#
#     Budget in USD  Awards  Popular
# 2     56013723.35       0        0
# 4             NaN       0        0
# 21    83518205.47       0        0

# %%
print("\nDBSCAN Outlier Detection:")
dbscan_outliers = outhandler.detect_outliers_dbscan(data.copy(), 'Rating')
dbscan_outliers
# Out:
# DBSCAN Outlier Detection:
#      Movie Id        Genre Release Date    Rating  \
# 2   UBWUVIHEL    Adventure   08/05/1996  3.116053
# 4   WMLWHTAMN      Fantasy   28/10/2011  5.250991
# 14  MTUOJCLUA       Horror   03/03/1989  6.913383
# 21  RQMTIJYHD  Documentary   15/08/1997  5.395632
# 28  ZZIBKYJID     Thriller   02/05/2019  5.720490
#
#                                               Summary Shooting Location  \
# 2   A lost civilization is rediscovered deep withi...            Sydney
# 4   A young inventor builds a time machine and emb...            Sydney
# 14  A group of teenagers explore a seemingly aband...            Sydney
# 21  A historical drama depicting a pivotal moment ...             Tokyo
# 28  A suspenseful thriller about a family trapped ...          New York
#
#     Budget in USD  Awards  Popular
# 2    5.601372e+07       0        0
# 4             NaN       0        0
# 14   3.267364e+06       0        0
# 21   8.351821e+07       0        0
# ...

# %% [markdown]
# ##**Scaling**

# %%
scaler = Scaler()

# %%
print("Min-Max Scaling:")
min_max_scaled_data = scaler.min_max_scale(data.copy(), 'Rating')
min_max_scaled_data
# Out:
# Min-Max Scaling:
#      Movie Id            Genre Release Date    Rating  \
# 0   TOYHANVUR           Horror   07/07/1985  0.984796
# 1   CORCILSLF      Documentary   05/08/1999  0.712060
# 2   UBWUVIHEL        Adventure   08/05/1996  0.000000
# 3   CGHMHKJHH          Fantasy   21/07/2018  0.845497
# 4   WMLWHTAMN          Fantasy   28/10/2011  0.316919
# 5   REKCPGLOJ           Comedy   04/06/2013  0.825428
# 6   GSDOQQRPD          Western   25/12/1995  0.901911
# 7   VMIYHZNZJ        Adventure   23/03/2018  0.941643
# 8   XVHGPYBBL          Mystery   19/06/2002  0.892121
# 9   NNZFDYZTH          History   16/02/2019  0.907905
# 10  VZTEXQGBB           Comedy   22/01/2018  0.860455
# 11  XSPIAJYJM          Fantasy   19/11/1985  0.808323
# 12  VFXKEREAP          Fantasy   29/07/1992  0.686785
# 13  MCCASXIDK            Crime   26/12/2003  0.981447
# 14  MTUOJCLUA           Horror   03/03/1989  0.563691
# 15  DBQTOTADE            Drama   23/10/1990  0.766111
# ...

# %%
print("\nStandard Scaling:")
standard_scaled_data = scaler.standard_scale(data.copy(), 'Budget in USD')
standard_scaled_data
# Out:
# Standard Scaling:
#      Movie Id            Genre Release Date    Rating  \
# 0   TOYHANVUR           Horror   07/07/1985  9.750176
# 1   CORCILSLF      Documentary   05/08/1999  7.912876
# 2   UBWUVIHEL        Adventure   08/05/1996  3.116053
# 3   CGHMHKJHH          Fantasy   21/07/2018  8.811783
# 4   WMLWHTAMN          Fantasy   28/10/2011  5.250991
# 5   REKCPGLOJ           Comedy   04/06/2013  8.676586
# 6   GSDOQQRPD          Western   25/12/1995  9.191819
# 7   VMIYHZNZJ        Adventure   23/03/2018  9.459478
# 8   XVHGPYBBL          Mystery   19/06/2002  9.125866
# 9   NNZFDYZTH          History   16/02/2019  9.232197
# 10  VZTEXQGBB           Comedy   22/01/2018  8.912548
# 11  XSPIAJYJM          Fantasy   19/11/1985  8.561358
# 12  VFXKEREAP          Fantasy   29/07/1992  7.742613
# 13  MCCASXIDK            Crime   26/12/2003  9.727619
# 14  MTUOJCLUA           Horror   03/03/1989  6.913383
# 15  DBQTOTADE            Drama   23/10/1990  8.276999
# ...

# %%
print("\nRobust Scaling:")
robust_scaled_data = scaler.robust_scale(data.copy(), 'Rating')
robust_scaled_data
# Out:
# Robust Scaling:
#      Movie Id            Genre Release Date    Rating  \
# 0   TOYHANVUR           Horror   07/07/1985  0.567146
# 1   CORCILSLF      Documentary   05/08/1999 -0.543281
# 2   UBWUVIHEL        Adventure   08/05/1996 -3.442385
# 3   CGHMHKJHH          Fantasy   21/07/2018  0.000000
# 4   WMLWHTAMN          Fantasy   28/10/2011 -2.152071
# 5   REKCPGLOJ           Comedy   04/06/2013 -0.081710
# 6   GSDOQQRPD          Western   25/12/1995  0.229686
# 7   VMIYHZNZJ        Adventure   23/03/2018  0.391454
# 8   XVHGPYBBL          Mystery   19/06/2002  0.189825
# 9   NNZFDYZTH          History   16/02/2019  0.254090
# 10  VZTEXQGBB           Comedy   22/01/2018  0.060900
# 11  XSPIAJYJM          Fantasy   19/11/1985 -0.151352
# 12  VFXKEREAP          Fantasy   29/07/1992 -0.646185
# 13  MCCASXIDK            Crime   26/12/2003  0.553513
# 14  MTUOJCLUA           Horror   03/03/1989 -1.147355
# 15  DBQTOTADE            Drama   23/10/1990 -0.323213
# ...

# %%
print("\nMax-Abs Scaling:")
max_abs_scaled_data = scaler.max_abs_scale(data.copy(), 'Rating')
max_abs_scaled_data
# Out:
# Max-Abs Scaling:
#      Movie Id            Genre Release Date    Rating  \
# 0   TOYHANVUR           Horror   07/07/1985  0.989604
# 1   CORCILSLF      Documentary   05/08/1999  0.803126
# 2   UBWUVIHEL        Adventure   08/05/1996  0.316267
# 3   CGHMHKJHH          Fantasy   21/07/2018  0.894361
# 4   WMLWHTAMN          Fantasy   28/10/2011  0.532955
# 5   REKCPGLOJ           Comedy   04/06/2013  0.880639
# 6   GSDOQQRPD          Western   25/12/1995  0.932933
# 7   VMIYHZNZJ        Adventure   23/03/2018  0.960100
# 8   XVHGPYBBL          Mystery   19/06/2002  0.926239
# 9   NNZFDYZTH          History   16/02/2019  0.937031
# 10  VZTEXQGBB           Comedy   22/01/2018  0.904588
# 11  XSPIAJYJM          Fantasy   19/11/1985  0.868944
# 12  VFXKEREAP          Fantasy   29/07/1992  0.785845
# 13  MCCASXIDK            Crime   26/12/2003  0.987315
# 14  MTUOJCLUA           Horror   03/03/1989  0.701681
# 15  DBQTOTADE            Drama   23/10/1990  0.840083
# ...

# %%
print("\nLog Scaling:")
log_scaled_data = scaler.log_scale(data.copy(), 'Rating')
log_scaled_data
# Out:
# Log Scaling:
#      Movie Id            Genre Release Date    Rating  \
# 0   TOYHANVUR           Horror   07/07/1985  2.374922
# 1   CORCILSLF      Documentary   05/08/1999  2.187497
# 2   UBWUVIHEL        Adventure   08/05/1996  1.414895
# 3   CGHMHKJHH          Fantasy   21/07/2018  2.283584
# 4   WMLWHTAMN          Fantasy   28/10/2011  1.832740
# 5   REKCPGLOJ           Comedy   04/06/2013  2.269709
# 6   GSDOQQRPD          Western   25/12/1995  2.321585
# 7   VMIYHZNZJ        Adventure   23/03/2018  2.347509
# 8   XVHGPYBBL          Mystery   19/06/2002  2.315093
# 9   NNZFDYZTH          History   16/02/2019  2.325539
# 10  VZTEXQGBB           Comedy   22/01/2018  2.293801
# 11  XSPIAJYJM          Fantasy   19/11/1985  2.257730
# 12  VFXKEREAP          Fantasy   29/07/1992  2.168209
# 13  MCCASXIDK            Crime   26/12/2003  2.372822
# 14  MTUOJCLUA           Horror   03/03/1989  2.068555
# 15  DBQTOTADE            Drama   23/10/1990  2.227538
# ...

# %%
print("\nZ-Score Scaling:")
z_score_scaled_data = scaler.z_score(data.copy(), 'Rating')
z_score_scaled_data
# Out:
# Z-Score Scaling:
#      Movie Id            Genre Release Date    Rating  \
# 0   TOYHANVUR           Horror   07/07/1985  0.915482
# 1   CORCILSLF      Documentary   05/08/1999 -0.208226
# 2   UBWUVIHEL        Adventure   08/05/1996 -3.142005
# 3   CGHMHKJHH          Fantasy   21/07/2018  0.341553
# 4   WMLWHTAMN          Fantasy   28/10/2011 -1.836258
# 5   REKCPGLOJ           Comedy   04/06/2013  0.258866
# 6   GSDOQQRPD          Western   25/12/1995  0.573986
# 7   VMIYHZNZJ        Adventure   23/03/2018  0.737689
# 8   XVHGPYBBL          Mystery   19/06/2002  0.533649
# 9   NNZFDYZTH          History   16/02/2019  0.598682
# 10  VZTEXQGBB           Comedy   22/01/2018  0.403182
# 11  XSPIAJYJM          Fantasy   19/11/1985  0.188391
# 12  VFXKEREAP          Fantasy   29/07/1992 -0.312361
# 13  MCCASXIDK            Crime   26/12/2003  0.901686
# 14  MTUOJCLUA           Horror   03/03/1989 -0.819525
# 15  DBQTOTADE            Drama   23/10/1990  0.014475
# ...

# %%
print("\nBox-Cox Scaling:")
# Box-Cox requires all positive values, let's shift data for this test
data_shifted = data.copy()
data_shifted['Rating'] = data_shifted['Rating'] + 1
box_cox_scaled_data = scaler.box_cox_scale(data_shifted, 'Rating')
box_cox_scaled_data[['Rating']]
# Out:
# Box-Cox Scaling:
#       Rating
# 0   1.260672
# 1  -0.568024
# 2  -1.997456
# 3   0.187826
# 4  -1.727196
# 5   0.058555
# 6   0.583887
# 7   0.893545
# 8   0.511575
# 9   0.628924
# 10  0.288058
# 11 -0.047038
# 12 -0.685718
# 13  1.230991
# 14 -1.160452
# 15 -0.290313
# 16 -0.784001
# 17  1.071653
# 18  1.328409
# 19  0.623477
# 20 -0.606515
# 21 -1.693786
# 22 -0.241622
# 23 -1.004493
# 24  0.819130
# 25  1.398044
# 26  0.473522
# 27  1.057496
# 28 -1.609151

# %%
print("\nYeo-Johnson Scaling:")
yeo_johnson_scaled_data = scaler.yeo_johnson_scale(data.copy(), 'Rating')
yeo_johnson_scaled_data[['Rating']]
# Out:
# Yeo-Johnson Scaling:
#       Rating
# 0   1.260672
# 1  -0.568024
# 2  -1.997456
# 3   0.187826
# 4  -1.727196
# 5   0.058555
# 6   0.583887
# 7   0.893545
# 8   0.511575
# 9   0.628924
# 10  0.288058
# 11 -0.047038
# 12 -0.685718
# 13  1.230991
# 14 -1.160452
# 15 -0.290313
# 16 -0.784001
# 17  1.071653
# 18  1.328409
# 19  0.623477
# 20 -0.606515
# 21 -1.693786
# 22 -0.241622
# 23 -1.004493
# 24  0.819130
# 25  1.398044
# 26  0.473522
# 27  1.057496
# 28 -1.609151

# %%
print("\nQuantile Transformation (Uniform):")
quantile_transformed_uniform_data = scaler.quantile_transform(data.copy(), 'Rating', output_distribution='uniform')
quantile_transformed_uniform_data[['Rating']]
# Out:
# Quantile Transformation (Uniform):
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (100) is greater than the total number of samples (29). n_quantiles is set to n_samples.
#   warnings.warn(
#       Rating
# 0   0.928571
# 1   0.321429
# 2   0.000000
# 3   0.500000
# 4   0.035714
# 5   0.464286
# 6   0.642857
# 7   0.785714
# 8   0.607143
# 9   0.714286
# 10  0.535714
# 11  0.428571
# 12  0.250000
# 13  0.892857
# 14  0.142857
# 15  0.357143
# 16  0.214286
# 17  0.857143
# 18  0.964286
# 19  0.678571
# 20  0.285714
# 21  0.071429
# 22  0.392857
# 23  0.178571
# 24  0.750000
# 25  1.000000
# 26  0.571429
# 27  0.821429
# 28  0.107143

# %%
print("\nQuantile Transformation (Normal):")
quantile_transformed_normal_data = scaler.quantile_transform(data.copy(), 'Rating', output_distribution='normal')
quantile_transformed_normal_data[['Rating']]
# Out:
# Quantile Transformation (Normal):
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_data.py:2627: UserWarning: n_quantiles (100) is greater than the total number of samples (29). n_quantiles is set to n_samples.
#   warnings.warn(
#       Rating
# 0   1.465234
# 1  -0.463708
# 2  -5.199338
# 3   0.000000
# 4  -1.802743
# 5  -0.089642
# 6   0.366106
# 7   0.791639
# 8   0.271880
# 9   0.565949
# 10  0.089642
# 11 -0.180012
# 12 -0.674490
# 13  1.241867
# 14 -1.067571
# 15 -0.366106
# 16 -0.791639
# 17  1.067571
# 18  1.802743
# 19  0.463708
# 20 -0.565949
# 21 -1.465234
# 22 -0.271880
# 23 -0.920823
# 24  0.674490
# 25  5.199338
# 26  0.180012
# 27  0.920823
# 28 -1.241867

# %%
print("\nInverse Log Scaling:")
inverse_log_scaled_data = scaler.log_scale(data.copy(), 'Rating')
inverse_log_scaled_data = scaler.inverse_log_scale(inverse_log_scaled_data, 'Rating')
inverse_log_scaled_data[['Rating']]
# Out:
# Inverse Log Scaling:
#       Rating
# 0   9.750176
# 1   7.912876
# 2   3.116053
# 3   8.811783
# 4   5.250991
# 5   8.676586
# 6   9.191819
# 7   9.459478
# 8   9.125866
# 9   9.232197
# 10  8.912548
# 11  8.561358
# 12  7.742613
# 13  9.727619
# 14  6.913383
# 15  8.276999
# 16  7.591583
# 17  9.603778
# 18  9.801080
# 19  9.227341
# 20  7.858370
# 21  5.395632
# 22  8.336223
# 23  7.216878
# 24  9.397201
# 25  9.852601
# 26  9.090585
# 27  9.592543
# 28  5.720490

# %%
print("\nSquare Root Scaling:")
square_root_scaled_data = scaler.square_root_scale(data.copy(), 'Rating')
square_root_scaled_data[['Rating']]
# Out:
# Square Root Scaling:
#       Rating
# 0   3.122527
# 1   2.812984
# 2   1.765234
# 3   2.968465
# 4   2.291504
# 5   2.945605
# 6   3.031801
# 7   3.075627
# 8   3.020905
# 9   3.038453
# 10  2.985389
# 11  2.925980
# 12  2.782555
# 13  3.118913
# 14  2.629331
# 15  2.876977
# 16  2.755283
# 17  3.098996
# 18  3.130668
# 19  3.037654
# 20  2.803278
# 21  2.322850
# 22  2.887252
# 23  2.686425
# 24  3.065485
# 25  3.138885
# 26  3.015060
# 27  3.097183
# 28  2.391755

# %%
print("\nReciprocal Scaling:")
reciprocal_scaled_data = scaler.reciprocal_scale(data.copy(), 'Rating')
reciprocal_scaled_data[['Rating']]
# Out:
# Reciprocal Scaling:
#       Rating
# 0   0.102562
# 1   0.126376
# 2   0.320919
# 3   0.113484
# 4   0.190440
# 5   0.115253
# 6   0.108792
# 7   0.105714
# 8   0.109579
# 9   0.108317
# 10  0.112201
# 11  0.116804
# 12  0.129155
# 13  0.102800
# 14  0.144647
# 15  0.120817
# 16  0.131725
# 17  0.104126
# 18  0.102030
# 19  0.108374
# 20  0.127253
# 21  0.185335
# 22  0.119958
# 23  0.138564
# 24  0.106415
# 25  0.101496
# 26  0.110004
# 27  0.104248
# 28  0.174810

# %% [markdown]
# ##**Text Cleaner**

# %%
cleaner = TextCleaner()

# %%
print("Original Summary:")
data['Summary'][0]
# Out:
# Original Summary:
# 'A group of college students get more than they bargained for when they spend a weekend at a haunted house.'

# %%
print("\nStopwords Removal:")
cleaned_data = cleaner.remove_stopwords_column(data.copy(), 'Summary')
print(cleaned_data['Summary'][0])
# Out:
# Stopwords Removal:
# group college students get bargained spend weekend haunted house.

# %%
print("\nTo Lowercase:")
cleaned_data = cleaner.to_lowercase_column(data.copy(), 'Summary')
print(cleaned_data['Summary'][0])
# Out:
# To Lowercase:
# a group of college students get more than they bargained for when they spend a weekend at a haunted house.

# %%
print("\nRemove Punctuation:")
cleaned_data = cleaner.remove_punctuation_column(data.copy(), 'Summary')
print(cleaned_data['Summary'][0])
# Out:
# Remove Punctuation:
# A group of college students get more than they bargained for when they spend a weekend at a haunted house

# %%
print("\nLemmatize:")
cleaned_data = cleaner.lemmatize_column(data.copy(), 'Summary')
print(cleaned_data['Summary'][0])
# Out:
# Lemmatize:
# A group of college student get more than they bargained for when they spend a weekend at a haunted house.

# %%
print("\nRemove Numbers:")
cleaned_data = cleaner.remove_numbers_column(data.copy(), 'Summary')
print(cleaned_data['Summary'][0])
# Out:
# Remove Numbers:
# A group of college students get more than they bargained for when they spend a weekend at a haunted house.

# %%
print("\nRemove Extra Whitespace:")
cleaned_data = cleaner.remove_extra_whitespace_column(data.copy(), 'Summary')
print(cleaned_data['Summary'][0])
# Out:
# Remove Extra Whitespace:
# A group of college students get more than they bargained for when they spend a weekend at a haunted house.

# %%
print("\nStem Words:")
cleaned_data = cleaner.stem_words_column(data.copy(), 'Summary')
print(cleaned_data['Summary'][0])
# Out:
# Stem Words:
# a group of colleg student get more than they bargain for when they spend a weekend at a haunt house.

# %%
datademo = {
        'text': [
            "Hello World! This is a test.",
            "Check out this link: https://example.com",
            "U r amazing! LOL",
            "Text with numbers 12345 and punctuations!!!",
            "<html>HTML content</html>",
            "   Extra   whitespace   ",
            "Spellng mistkes are cmmon",
            "Emojis are fun 😊😂👍",
            "Here's a contraction: don't",
            "Abbreviations like idk and lol"
        ]
    }
df = pd.DataFrame(datademo)

# %%
print("\nRemove HTML Tags:")
for text in df['text']:
        print(cleaner.remove_html_tags(text))
# Out:
# Remove HTML Tags:
# Hello World! This is a test.
# Check out this link: https://example.com
# U r amazing! LOL
# Text with numbers 12345 and punctuations!!!
# HTML content
#    Extra   whitespace
# Spellng mistkes are cmmon
# Emojis are fun 😊😂👍
# Here's a contraction: don't
# Abbreviations like idk and lol
# /usr/local/lib/python3.10/dist-packages/data_preprocessing_lib_byarat/text_cleaner.py:67: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   return BeautifulSoup(text, "html.parser").get_text()

# %%
print("\nReplace Contractions:")
cleaned_data = cleaner.replace_contractions_column(data.copy(), 'Summary')
print(cleaned_data['Summary'][0])
# Out:
# Replace Contractions:
# A group of college students get more than they bargained for when they spend a weekend at a haunted house.

# %%
print("\nReplace Contractions in df:")
for text in df['text']:
        print(cleaner.replace_contractions(text))
# Out:
# Replace Contractions in df:
# Hello World! This is a test.
# Check out this link: https://example.com
# YOU r amazing! LOL
# Text with numbers 12345 and punctuations!!!
# <html>HTML content</html>
#    Extra   whitespace
# Spellng mistkes are cmmon
# Emojis are fun 😊😂👍
# Here is a contraction: do not
# Abbreviations like i do not know and lol

# %%
print("\nExpand Abbreviations:")
for text in df['text']:
        print(cleaner.expand_abbreviations(text))
# Out:
# Expand Abbreviations:
# Hello World! This is a test.
# Check out this link: https://example.com
# U are amazing! LOL
# Text with numbers 12345 and punctuations!!!
# <html>HTML content</html>
# Extra whitespace
# Spellng mistkes are cmmon
# Emojis are fun 😊😂👍
# Here's a contraction: don't
# Abbreviations like I don't know and laughing out loud

# %%
print("\nRemove Special Characters:")
for text in df['text']:
        print(cleaner.remove_special_characters(text))
# Out:
# Remove Special Characters:
# Hello World This is a test
# Check out this link httpsexamplecom
# U r amazing LOL
# Text with numbers 12345 and punctuations
# htmlHTML contenthtml
#    Extra   whitespace
# Spellng mistkes are cmmon
# Emojis are fun
# Heres a contraction dont
# Abbreviations like idk and lol

# %%
print("\nRemove Special Characters:")
cleaned_data = cleaner.remove_special_characters_column(data.copy(), 'Summary')
print(cleaned_data['Summary'][0])
# Out:
# Remove Special Characters:
# A group of college students get more than they bargained for when they spend a weekend at a haunted house

# %%
print("\nRemove URLs:")
for text in df['text']:
        print(cleaner.remove_urls(text))
# Out:
# Remove URLs:
# Hello World! This is a test.
# Check out this link:
# U r amazing! LOL
# Text with numbers 12345 and punctuations!!!
# <html>HTML content</html>
#    Extra   whitespace
# Spellng mistkes are cmmon
# Emojis are fun 😊😂👍
# Here's a contraction: don't
# Abbreviations like idk and lol

# %%
print("\nRemove HTML Tags:")
for text in df['text']:
        print(cleaner.remove_html_tags(text))
# Out:
# Remove HTML Tags:
# Hello World! This is a test.
# Check out this link: https://example.com
# U r amazing! LOL
# Text with numbers 12345 and punctuations!!!
# HTML content
#    Extra   whitespace
# Spellng mistkes are cmmon
# Emojis are fun 😊😂👍
# Here's a contraction: don't
# Abbreviations like idk and lol
# /usr/local/lib/python3.10/dist-packages/data_preprocessing_lib_byarat/text_cleaner.py:67: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   return BeautifulSoup(text, "html.parser").get_text()

# %%
print("\nSpell Check:")
cleaned_data = cleaner.spell_check_column(data.copy(), 'Summary')
print(cleaned_data['Summary'][0])
# Out:
# Spell Check:
# A group of college students get more than they bargained for when they spend a weekend at a haunted house

# %%
print("\nRemove Emojis:")
for text in df['text']:
        print(cleaner.remove_emojis(text))
# Out:
# Remove Emojis:
# Hello World! This is a test.
# Check out this link: https://example.com
# U r amazing! LOL
# Text with numbers 12345 and punctuations!!!
# <html>HTML content</html>
#    Extra   whitespace
# Spellng mistkes are cmmon
# Emojis are fun
# Here's a contraction: don't
# Abbreviations like idk and lol

# %%
cleaned_data = data.copy()
cleaned_data['Summary_cleaned'] = cleaner.clean_column(cleaned_data, 'Summary')['Summary']

print("Orijinal ve Temizlenmiş Metinler:")
print(cleaned_data[['Summary', 'Summary_cleaned']].head())

cleaned_data['Summary_no_stopwords'] = cleaner.remove_stopwords_column(data.copy(), 'Summary')['Summary']
cleaned_data['Summary_lowercase'] = cleaner.to_lowercase_column(data.copy(), 'Summary')['Summary']
cleaned_data['Summary_no_punctuation'] = cleaner.remove_punctuation_column(data.copy(), 'Summary')['Summary']
cleaned_data['Summary_lemmatized'] = cleaner.lemmatize_column(data.copy(), 'Summary')['Summary']
cleaned_data['Summary_no_numbers'] = cleaner.remove_numbers_column(data.copy(), 'Summary')['Summary']
cleaned_data['Summary_no_whitespace'] = cleaner.remove_extra_whitespace_column(data.copy(), 'Summary')['Summary']
cleaned_data['Summary_stemmed'] = cleaner.stem_words_column(data.copy(), 'Summary')['Summary']
cleaned_data['Summary_no_html'] = cleaner.remove_html_tags_column(data.copy(), 'Summary')['Summary']
cleaned_data['Summary_no_contractions'] = cleaner.replace_contractions_column(data.copy(), 'Summary')['Summary']
cleaned_data['Summary_expanded'] = cleaner.expand_abbreviations_column(data.copy(), 'Summary')['Summary']
cleaned_data['Summary_no_special_chars'] = cleaner.remove_special_characters_column(data.copy(), 'Summary')['Summary']
cleaned_data['Summary_no_urls'] = cleaner.remove_urls_column(data.copy(), 'Summary')['Summary']
cleaned_data['Summary_no_emojis'] = cleaner.remove_emojis_column(data.copy(), 'Summary')['Summary']
cleaned_data['Summary_spell_checked'] = cleaner.spell_check_column(data.copy(), 'Summary')['Summary']

print("Temizlenmiş Metinler DataFrame:")
cleaned_data
# Out:
# Orijinal ve Temizlenmiş Metinler:
#                                              Summary  \
# 0  group college student get bargained spend week...
# 1  documentary shed light devastating effect clim...
# 2  lost civilization rediscovered deep within ama...
# 3  young inventor build time machine embarks jour...
# 4  young inventor build time machine embarks jour...
#
#                                      Summary_cleaned
# 0  group college student get bargained spend week...
# 1  documentary shed light devastating effect clim...
# 2  lost civilization rediscovered deep within ama...
# 3  young inventor build time machine embarks jour...
# 4  young inventor build time machine embarks jour...
# Temizlenmiş Metinler DataFrame:
#      Movie Id            Genre Release Date    Rating  \
# 0   TOYHANVUR           Horror   07/07/1985  9.750176
# 1   CORCILSLF      Documentary   05/08/1999  7.912876
# 2   UBWUVIHEL        Adventure   08/05/1996  3.116053
# ...
